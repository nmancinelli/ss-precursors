# %%
import warnings
warnings.filterwarnings('ignore')

import sqlite3
conn = sqlite3.connect("ss.db")
cur  = conn.cursor()

import time
import os

import pandas as pd

# %%
#If downloads table does not exist, create one 

#Uncomment to delete downloads table, must restart downloads if that happens
#cur.execute('''DROP TABLE downloads''')

try:
    qry = """SELECT bouncepoints_full.ID_Full, 
    bouncepoints_full.Event, 
    bouncepoints_full.Station, 
    bouncepoints_full.Network, 
    bouncepoints_full.Range, 
    bouncepoints_full.MidLat, 
    bouncepoints_full.MidLon, 
    bouncepoints_full.EvtTime, 
    bouncepoints_full.BAzimuth, 
    bouncepoints_full.EvtDep, 
    downloads.Success,
    downloads.Attempted
    FROM bouncepoints_full 
    LEFT JOIN downloads 
    ON bouncepoints_full.ID_Full=downloads.ID_Full
    WHERE bouncepoints_full.MidLat > 0
    AND bouncepoints_full.MidLat < 75
    AND bouncepoints_full.MidLon < -60
    AND bouncepoints_full.MidLon > -135
    AND bouncepoints_full.EvtDep <= 75
    AND ((bouncepoints_full.Range > 95
    AND bouncepoints_full.Range < 115)
    OR (bouncepoints_full.Range > 140
    AND bouncepoints_full.Range < 165))
    ORDER BY EvtTime"""
    
    dfds = pd.read_sql_query(qry, conn, index_col=["ID_Full"])
    dfds = dfds.query('Attempted != "True"')
    
except:
    dfds = pd.DataFrame(columns=["ID_Full","Attempted","Success","Failure_Reason"])
    dfds.to_sql('downloads',conn, dtype = {"ID_Full" : 'TEXT',
                               "Attempted" : "BOOLEAN",          
                               "Success" : "BOOLEAN",
                               "Failure_Reason" : "TEXT"})
    
    dfds = pd.read_sql_query("SELECT ID_Full, Event, Station, Network, Range, MidLat, MidLon, EvtTime, BAzimuth from bouncepoints_full", conn, index_col=["ID_Full"])
    dfds = dfds.query('MidLat > 30 and MidLat < 75 and MidLon < -60 and MidLon > -135')
    
#from matplotlib import pylab as plt
#plt.style.use('ggplot')
#dfds.hist()
#plt.show()
dfds
# Out:
#                                   Event Station Network       Range  \
# ID_Full
# C200610100802A.IU.KBS    C200610100802A     KBS      IU  152.822914
# C200610100802A.IU.KEV    C200610100802A     KEV      IU  160.946665
# C200610100802A.IU.KONO   C200610100802A    KONO      IU  154.846036
# C200610121805A.AT.PMR    C200610121805A     PMR      AT  111.530158
# C200610121805A.AT.SIT    C200610121805A     SIT      AT  103.145877
# C200610121805A.CN.BBB    C200610121805A     BBB      CN   96.779730
# C200610121805A.CN.FRB    C200610121805A     FRB      CN   95.043882
# C200610121805A.CN.INK    C200610121805A     INK      CN  109.416730
# C200610121805A.CN.RES    C200610121805A     RES      CN  107.054694
# C200610121805A.CN.YKW1   C200610121805A    YKW1      CN   99.742739
# C200610121805A.CN.YKW2   C200610121805A    YKW2      CN   99.735881
# C200610121805A.CN.YKW3   C200610121805A    YKW3      CN   99.841413
# C200610121805A.CN.YKW4   C200610121805A    YKW4      CN   99.821654
# C200610121805A.GE.DAG    C200610121805A     DAG      GE  112.933835
# C200610121805A.GE.SFJD   C200610121805A    SFJD      GE   99.607974
# C200610121805A.GE.SUMG   C200610121805A    SUMG      GE  106.415187
# C200610121805A.IC.MDJ    C200610121805A     MDJ      IC  158.726668
# C200610121805A.II.ALE    C200610121805A     ALE      II  113.940966
# C200610121805A.II.ERM    C200610121805A     ERM      II  150.277931
# C200610121805A.II.KDAK   C200610121805A    KDAK      II  111.446934
# C200610121805A.IU.COLA   C200610121805A    COLA      IU  112.477311
# C200610121805A.IU.MA2    C200610121805A     MA2      IU  140.124380
# C200610121805A.IU.SFJD   C200610121805A    SFJD      IU   99.608159
# C200610121805A.IU.YSS    C200610121805A     YSS      IU  149.378482
# C200610121805A.US.EGAK   C200610121805A    EGAK      US  109.927520
# C200610121805A.US.WRAK   C200610121805A    WRAK      US  101.474177
# C200610121805A.XG.FFANG  C200610121805A   FFANG      XG  164.971158
# C200610121805A.XG.HQI    C200610121805A     HQI      XG  164.856922
# C200610121805A.XG.LJIA   C200610121805A    LJIA      XG  164.863454
# C200610121805A.XG.LJPZ   C200610121805A    LJPZ      XG  164.926153
# ...                                 ...     ...     ...         ...
# C201712080209A.N4.Y57A   C201712080209A    Y57A      N4  112.701545
# C201712080209A.N4.Y58A   C201712080209A    Y58A      N4  113.218481
# C201712080209A.N4.Y60A   C201712080209A    Y60A      N4  114.376236
# C201712080209A.N4.Z47B   C201712080209A    Z47B      N4  106.512805
# C201712080209A.N4.Z51A   C201712080209A    Z51A      N4  108.759884
# C201712080209A.NM.PLAL   C201712080209A    PLAL      NM  107.277245
# C201712080209A.PE.PARS   C201712080209A    PARS      PE  114.768405
# C201712080209A.PM.PMOZ   C201712080209A    PMOZ      PM  164.208112
# C201712080209A.PM.ROSA   C201712080209A    ROSA      PM  154.512932
# C201712080209A.TA.KMSC   C201712080209A    KMSC      TA  112.406498
# C201712080209A.TA.O53A   C201712080209A    O53A      TA  114.338320
# C201712080209A.TA.P49A   C201712080209A    P49A      TA  111.565527
# C201712080209A.TA.P52A   C201712080209A    P52A      TA  113.460530
# C201712080209A.TA.TIGA   C201712080209A    TIGA      TA  109.204306
# C201712080209A.US.ACSO   C201712080209A    ACSO      US  113.063699
# C201712080209A.US.BLA    C201712080209A     BLA      US  113.854400
# C201712080209A.US.BRAL   C201712080209A    BRAL      US  106.406561
# C201712080209A.US.GOGA   C201712080209A    GOGA      US  110.103964
# C201712080209A.US.LRAL   C201712080209A    LRAL      US  107.255995
# C201712080209A.US.NHSC   C201712080209A    NHSC      US  112.520847
# C201712080209A.US.TZTN   C201712080209A    TZTN      US  111.276469
# C201712080209A.US.VBMS   C201712080209A    VBMS      US  104.227528
# C201712131803A.AT.SIT    C201712131803A     SIT      AT  156.394166
# C201712131803A.TA.S31K   C201712131803A    S31K      TA  157.036997
# C201712131803A.TA.S32K   C201712131803A    S32K      TA  156.076661
# C201712131803A.TA.T33K   C201712131803A    T33K      TA  155.072813
# C201712131803A.TA.U33K   C201712131803A    U33K      TA  154.992478
# C201712131803A.TA.U35K   C201712131803A    U35K      TA  153.266415
# C201712131803A.TA.V35K   C201712131803A    V35K      TA  153.956651
# C201712131803A.US.WRAK   C201712131803A    WRAK      US  154.652128
#
#                             MidLat      MidLon                      EvtTime  \
# ID_Full
# C200610100802A.IU.KBS    18.700125 -104.378910  2006-10-10T08:02:57.400000Z
# C200610100802A.IU.KEV    18.962970  -88.233213  2006-10-10T08:02:57.400000Z
# C200610100802A.IU.KONO    4.189729  -62.517216  2006-10-10T08:02:57.400000Z
# C200610121805A.AT.PMR    18.461563  -97.886211  2006-10-12T18:06:04.200000Z
# C200610121805A.AT.SIT    14.696971  -95.961148  2006-10-12T18:06:04.200000Z
# C200610121805A.CN.BBB    11.539117  -95.142517  2006-10-12T18:06:04.200000Z
# C200610121805A.CN.FRB    16.028144  -70.837313  2006-10-12T18:06:04.200000Z
# C200610121805A.CN.INK    20.574850  -89.581198  2006-10-12T18:06:04.200000Z
# C200610121805A.CN.RES    21.800360  -77.388882  2006-10-12T18:06:04.200000Z
# C200610121805A.CN.YKW1   16.360766  -86.703244  2006-10-12T18:06:04.200000Z
# C200610121805A.CN.YKW2   16.341333  -86.759237  2006-10-12T18:06:04.200000Z
# C200610121805A.CN.YKW3   16.407997  -86.718113  2006-10-12T18:06:04.200000Z
# C200610121805A.CN.YKW4   16.378559  -86.785647  2006-10-12T18:06:04.200000Z
# C200610121805A.GE.DAG    24.079759  -61.493671  2006-10-12T18:06:04.200000Z
# C200610121805A.GE.SFJD   17.906776  -65.328293  2006-10-12T18:06:04.200000Z
# C200610121805A.GE.SUMG   21.090526  -63.468383  2006-10-12T18:06:04.200000Z
# C200610121805A.IC.MDJ    29.256846 -125.795420  2006-10-12T18:06:04.200000Z
# C200610121805A.II.ALE    25.477294  -70.747117  2006-10-12T18:06:04.200000Z
# C200610121805A.II.ERM    16.658233 -132.219683  2006-10-12T18:06:04.200000Z
# C200610121805A.II.KDAK   16.642676 -101.303971  2006-10-12T18:06:04.200000Z
# C200610121805A.IU.COLA   20.116696  -95.357183  2006-10-12T18:06:04.200000Z
# C200610121805A.IU.MA2    29.908492 -107.590529  2006-10-12T18:06:04.200000Z
# C200610121805A.IU.SFJD   17.906843  -65.328084  2006-10-12T18:06:04.200000Z
# C200610121805A.IU.YSS    23.275225 -125.128056  2006-10-12T18:06:04.200000Z
# C200610121805A.US.EGAK   19.402975  -93.692810  2006-10-12T18:06:04.200000Z
# C200610121805A.US.WRAK   14.137417  -95.175739  2006-10-12T18:06:04.200000Z
# C200610121805A.XG.FFANG  29.313739 -130.719541  2006-10-12T18:06:04.200000Z
# C200610121805A.XG.HQI    28.628293 -131.348631  2006-10-12T18:06:04.200000Z
# C200610121805A.XG.LJIA   29.379437 -130.565755  2006-10-12T18:06:04.200000Z
# C200610121805A.XG.LJPZ   29.308951 -130.689491  2006-10-12T18:06:04.200000Z
# ...                            ...         ...                          ...
# C201712080209A.N4.Y57A    2.606790 -130.679718  2017-12-08T02:10:03.000000Z
# C201712080209A.N4.Y58A    2.541655 -130.289287  2017-12-08T02:10:03.000000Z
# C201712080209A.N4.Y60A    2.659517 -129.635746  2017-12-08T02:10:03.000000Z
# C201712080209A.N4.Z47B    1.833160 -134.088738  2017-12-08T02:10:03.000000Z
# C201712080209A.N4.Z51A    1.971798 -132.723879  2017-12-08T02:10:03.000000Z
# C201712080209A.NM.PLAL    3.098105 -134.701354  2017-12-08T02:10:03.000000Z
# C201712080209A.PE.PARS    7.054421 -133.251436  2017-12-08T02:10:03.000000Z
# C201712080209A.PM.PMOZ    7.287515 -102.228741  2017-12-08T02:10:03.000000Z
# C201712080209A.PM.ROSA   15.556674 -114.018767  2017-12-08T02:10:03.000000Z
# C201712080209A.TA.KMSC    3.430307 -131.571016  2017-12-08T02:10:03.000000Z
# C201712080209A.TA.O53A    7.270759 -133.757205  2017-12-08T02:10:03.000000Z
# C201712080209A.TA.P49A    6.510703 -134.958305  2017-12-08T02:10:03.000000Z
# C201712080209A.TA.P52A    6.749244 -133.867405  2017-12-08T02:10:03.000000Z
# C201712080209A.TA.TIGA    0.614263 -131.305320  2017-12-08T02:10:03.000000Z
# C201712080209A.US.ACSO    7.132381 -134.514321  2017-12-08T02:10:03.000000Z
# C201712080209A.US.BLA     5.035580 -132.014525  2017-12-08T02:10:03.000000Z
# C201712080209A.US.BRAL    0.396477 -132.936086  2017-12-08T02:10:03.000000Z
# C201712080209A.US.GOGA    2.076258 -131.930801  2017-12-08T02:10:03.000000Z
# C201712080209A.US.LRAL    1.738297 -133.514531  2017-12-08T02:10:03.000000Z
# C201712080209A.US.NHSC    1.916682 -130.227027  2017-12-08T02:10:03.000000Z
# C201712080209A.US.TZTN    4.388062 -133.168720  2017-12-08T02:10:03.000000Z
# C201712080209A.US.VBMS    1.110038 -134.974544  2017-12-08T02:10:03.000000Z
# C201712131803A.AT.SIT     3.613442  -61.597845  2017-12-13T18:03:54.000000Z
# C201712131803A.TA.S31K    4.946525  -60.067468  2017-12-13T18:03:54.000000Z
# C201712131803A.TA.S32K    4.105877  -60.512143  2017-12-13T18:03:54.000000Z
# C201712131803A.TA.T33K    3.110272  -61.156439  2017-12-13T18:03:54.000000Z
# C201712131803A.TA.U33K    2.202061  -62.512031  2017-12-13T18:03:54.000000Z
# C201712131803A.TA.U35K    1.813102  -61.516928  2017-12-13T18:03:54.000000Z
# C201712131803A.TA.V35K    1.123444  -63.230205  2017-12-13T18:03:54.000000Z
# C201712131803A.US.WRAK    2.559007  -61.635071  2017-12-13T18:03:54.000000Z
#
#                            BAzimuth  EvtDep Success Attempted
# ID_Full
# C200610100802A.IU.KBS    299.257516    12.0    None      None
# C200610100802A.IU.KEV    300.006007    12.0    None      None
# C200610100802A.IU.KONO   256.790600    12.0    None      None
# C200610121805A.AT.PMR    116.433830    36.8    None      None
# C200610121805A.AT.SIT    128.342101    36.8    None      None
# C200610121805A.CN.BBB    134.384571    36.8    None      None
# C200610121805A.CN.FRB    182.992398    36.8    None      None
# C200610121805A.CN.INK    127.208409    36.8    None      None
# C200610121805A.CN.RES    159.665018    36.8    None      None
# C200610121805A.CN.YKW1   144.144759    36.8    None      None
# C200610121805A.CN.YKW2   144.051272    36.8    None      None
# C200610121805A.CN.YKW3   144.033380    36.8    None      None
# C200610121805A.CN.YKW4   143.930679    36.8    None      None
# C200610121805A.GE.DAG    228.133221    36.8    None      None
# C200610121805A.GE.SFJD   198.460266    36.8    None      None
# C200610121805A.GE.SUMG   209.534322    36.8    None      None
# C200610121805A.IC.MDJ     59.005380    36.8    None      None
# C200610121805A.II.ALE    189.044709    36.8    None      None
# C200610121805A.II.ERM     80.612827    36.8    None      None
# C200610121805A.II.KDAK   115.095380    36.8    None      None
# C200610121805A.IU.COLA   116.281752    36.8    None      None
# C200610121805A.IU.MA2     64.378300    36.8    None      None
# C200610121805A.IU.SFJD   198.460904    36.8    None      None
# C200610121805A.IU.YSS     71.954987    36.8    None      None
# C200610121805A.US.EGAK   121.846868    36.8    None      None
# C200610121805A.US.WRAK   130.712792    36.8    None      None
# C200610121805A.XG.FFANG   57.424014    36.8    None      None
# C200610121805A.XG.HQI     58.461981    36.8    None      None
# C200610121805A.XG.LJIA    57.349437    36.8    None      None
# C200610121805A.XG.LJPZ    57.440794    36.8    None      None
# ...                             ...     ...     ...       ...
# C201712080209A.N4.Y57A   247.760356    13.8    None      None
# C201712080209A.N4.Y58A   248.024940    13.8    None      None
# C201712080209A.N4.Y60A   248.678435    13.8    None      None
# C201712080209A.N4.Z47B   244.175054    13.8    None      None
# C201712080209A.N4.Z51A   245.466626    13.8    None      None
# C201712080209A.NM.PLAL   244.662884    13.8    None      None
# C201712080209A.PE.PARS   250.151541    13.8    None      None
# C201712080209A.PM.PMOZ   273.746852    13.8    None      None
# C201712080209A.PM.ROSA   280.009226    13.8    None      None
# C201712080209A.TA.KMSC   247.782362    13.8    None      None
# C201712080209A.TA.O53A   249.905705    13.8    None      None
# C201712080209A.TA.P49A   247.788650    13.8    None      None
# C201712080209A.TA.P52A   249.169122    13.8    None      None
# C201712080209A.TA.TIGA   245.532860    13.8    None      None
# C201712080209A.US.ACSO   248.965076    13.8    None      None
# C201712080209A.US.BLA    249.028722    13.8    None      None
# C201712080209A.US.BRAL   244.063618    13.8    None      None
# C201712080209A.US.GOGA   246.228952    13.8    None      None
# C201712080209A.US.LRAL   244.598172    13.8    None      None
# C201712080209A.US.NHSC   247.498351    13.8    None      None
# C201712080209A.US.TZTN   247.282553    13.8    None      None
# C201712080209A.US.VBMS   242.864558    13.8    None      None
# C201712131803A.AT.SIT    101.539490    20.1    None      None
# C201712131803A.TA.S31K    98.900205    20.1    None      None
# C201712131803A.TA.S32K   101.067339    20.1    None      None
# C201712131803A.TA.T33K   103.430421    20.1    None      None
# C201712131803A.TA.U33K   104.801620    20.1    None      None
# C201712131803A.TA.U35K   106.788342    20.1    None      None
# C201712131803A.TA.V35K   107.143970    20.1    None      None
# C201712131803A.US.WRAK   104.583565    20.1    None      None
#
# [52138 rows x 11 columns]

# %%
from obspy import UTCDateTime

from obspy.taup import TauPyModel

from obspy.clients.fdsn import Client

client = Client("IRIS")

model = TauPyModel('ak135')



#def save_error_dataframe(dataframe):
#    dfe.to_csv('errors.csv')
    
def insert_database_info(ID_Full):
    cur.execute("INSERT INTO downloads (ID_Full) VALUES ('%s')" % ID_Full)
    

def update_database_error(error_msg,ID_Full):
    cur.execute("UPDATE downloads SET Failure_Reason = '%s' WHERE ID_Full = '%s'" % (error_msg, ID_Full ) )
    cur.execute("UPDATE downloads SET Attempted = 'True' WHERE ID_Full = '%s'" % (ID_Full ) )
    
def update_database_status(success,ID_Full):
    cur.execute("UPDATE downloads SET Success = '%s' WHERE ID_Full = '%s'" % (success, ID_Full ) )
    cur.execute("UPDATE downloads SET Attempted = 'True' WHERE ID_Full = '%s'" % (ID_Full ) )

for bp in dfds.iterrows():
    etime = UTCDateTime(bp[1].EvtTime)
    sta = bp[1].Station
    net = bp[1].Network
    deldeg = bp[1].Range
    
    print("Working on    " + bp[0] )
    insert_database_info(bp[0])
    
    arrivals = model.get_travel_times(0.0, deldeg, phase_list = ['SS'])
    
    
    time_ss = arrivals[0].time
    
    t1 = etime + time_ss - 200
    t2 = etime + time_ss + 200
    
    clock=time.time()
    try:
        st = client.get_waveforms(net, sta, "*", "LH*", t1, t2, attach_response = True)
    except:
        err = 'No Data at %s.%s' % (net, sta)
        #print(err)
        #dfe.loc[bp[0],"Status"] = err
        update_database_error(err, bp[0])
        continue
    print('  step completed in %8.2e s' % (time.time() - clock) )
        
    

    try:
        st.remove_response(output='ACC', pre_filt=(0.005, 0.01, 0.5, 1.0))
    except ValueError as e:
        err = 'Response Error: %s' % e
        update_database_error(err, bp[0])
    except TypeError as e:
        err = 'Response Error: %s' % e
        update_database_error(err, bp[0])
    
    try:
        inv = client.get_stations(
            starttime=t1, endtime=t2, 
            network=net, sta=sta, 
            loc="*", channel="LH*", level="response")
        
        st.rotate('->ZNE', inventory = inv)
        st.rotate('NE->RT', back_azimuth = bp[1].BAzimuth)
    except ValueError as e:
        err = 'Rotation Error: %s' % e
        #print(err)
        #dfe.loc[bp[0],"Status"] = err
        update_database_error(err, bp[0])
        
        continue
    
    bpid = bp[0]
    
    directory = 'data/mseed/%s/' % (bp[1].Event)
    
    filename = directory + bpid + '.mseed'
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    trT = st[0]
    
    for tr in st:
        if 'T' in tr.stats.channel:
            trT = tr
    
    trT.resample(1)
    
    trT.write(filename)
    
    #dfe.loc[bp[0],"Status"] = 'OK'
    update_database_status(True, bp[0])
    
    #save_error_dataframe(dfe)
    conn.commit()
# Out:
# Working on    C200610100802A.IU.KBS
#   step completed in 4.09e+00 s
# Working on    C200610100802A.IU.KEV
#   step completed in 3.86e+00 s
# Working on    C200610100802A.IU.KONO
#   step completed in 3.60e+00 s
# Working on    C200610121805A.AT.PMR
# Working on    C200610121805A.AT.SIT
# Working on    C200610121805A.CN.BBB
#   step completed in 2.18e+00 s
# Working on    C200610121805A.CN.FRB
#   step completed in 2.38e+00 s
# Working on    C200610121805A.CN.INK
#   step completed in 2.49e+00 s
# Working on    C200610121805A.CN.RES
#   step completed in 2.61e+00 s
# Working on    C200610121805A.CN.YKW1
#   step completed in 2.29e+00 s
# Working on    C200610121805A.CN.YKW2
#   step completed in 3.31e+00 s
# Working on    C200610121805A.CN.YKW3
#   step completed in 1.92e+00 s
# Working on    C200610121805A.CN.YKW4
#   step completed in 2.35e+00 s
# Working on    C200610121805A.GE.DAG
# Working on    C200610121805A.GE.SFJD
# Working on    C200610121805A.GE.SUMG
#   step completed in 2.27e+00 s
# Working on    C200610121805A.IC.MDJ
#   step completed in 3.62e+00 s
# Working on    C200610121805A.II.ALE
#   step completed in 3.93e+00 s
# Working on    C200610121805A.II.ERM
#   step completed in 2.08e+00 s
# Working on    C200610121805A.II.KDAK
#   step completed in 4.27e+00 s
# Working on    C200610121805A.IU.COLA
#   step completed in 3.78e+00 s
# Working on    C200610121805A.IU.MA2
#   step completed in 2.01e+00 s
# Working on    C200610121805A.IU.SFJD
#   step completed in 4.22e+00 s
# Working on    C200610121805A.IU.YSS
#   step completed in 2.06e+00 s
# Working on    C200610121805A.US.EGAK
#   step completed in 2.07e+00 s
# Working on    C200610121805A.US.WRAK
#   step completed in 3.23e+00 s
# Working on    C200610121805A.XG.FFANG
# Working on    C200610121805A.XG.HQI
# Working on    C200610121805A.XG.LJIA
#   step completed in 1.97e+00 s
# Working on    C200610121805A.XG.LJPZ
#   step completed in 2.93e+00 s
# Working on    C200610121805A.XG.STZ
#   step completed in 1.96e+00 s
# Working on    C200610121805A.XG.WTANG
#   step completed in 1.94e+00 s
# Working on    C200610121805A.XG.XDIAN
#   step completed in 1.85e+00 s
# Working on    C200610121805A.XR.BMQ
#   step completed in 1.75e+00 s
# Working on    C200610121805A.XR.CBM
#   step completed in 1.95e+00 s
# Working on    C200610121805A.XR.CHS
#   step completed in 1.86e+00 s
# Working on    C200610121805A.XR.FRB
#   step completed in 1.89e+00 s
# Working on    C200610121805A.XR.GBN
#   step completed in 1.89e+00 s
# Working on    C200610121805A.XR.ICT
#   step completed in 1.80e+00 s
# Working on    C200610121805A.XR.LMW
#   step completed in 1.84e+00 s
# Working on    C200610121805A.XR.LVG
# Working on    C200610121805A.XR.PRB
#   step completed in 1.92e+00 s
# Working on    C200610121805A.XR.SAG
#   step completed in 2.16e+00 s
# Working on    C200610121805A.XR.TFS
#   step completed in 1.83e+00 s
# Working on    C200610121805A.XR.WSM
#   step completed in 1.79e+00 s
# Working on    C200610121805A.XR.YRT
#   step completed in 1.70e+00 s
# Working on    C200610121805A.XY.BN01
# Working on    C200610121805A.XY.BN02
# Working on    C200610121805A.XY.BN04
# Working on    C200610121805A.XY.BN05
# Working on    C200610121805A.XY.BN06
# Working on    C200610121805A.XY.BN07
# Working on    C200610121805A.XY.BN08
# Working on    C200610121805A.XY.BN09
# Working on    C200610121805A.XY.BN10
# Working on    C200610121805A.XY.BN11
# Working on    C200610121805A.XY.BN12
# Working on    C200610121805A.XY.BN13
# Working on    C200610121805A.XY.BN13A
# Working on    C200610121805A.XY.BN14
# Working on    C200610121805A.XY.BN15
# Working on    C200610121805A.XY.BN16
# Working on    C200610121805A.XY.BN17
# Working on    C200610121805A.XY.BN18
# Working on    C200610121805A.XY.BN19
# Working on    C200610121805A.XY.BN20
# Working on    C200610121805A.XY.BN21
# Working on    C200610121805A.XY.BN22
# Working on    C200610121805A.XY.BN23
# Working on    C200610121805A.XY.BS01
# Working on    C200610121805A.XY.BS02
# Working on    C200610121805A.XY.BS03
# Working on    C200610121805A.XY.BS04M
# Working on    C200610121805A.XY.BS05
# Working on    C200610121805A.XY.BS06
# Working on    C200610121805A.XY.BS07
# Working on    C200610121805A.XY.BS09
# Working on    C200610121805A.XY.BS10
# Working on    C200610121805A.XY.BS11
# Working on    C200610121805A.XY.BS12M
# Working on    C200610121805A.XY.BS13
# Working on    C200610121805A.XY.BS14
# Working on    C200610121805A.XY.BS15
# Working on    C200610121805A.XY.BS15A
# Working on    C200610121805A.XY.BS16
# Working on    C200610121805A.XY.BS17
# Working on    C200610121805A.XY.BS18
# Working on    C200610121805A.XY.BS19
# Working on    C200610121805A.XY.BS21
# Working on    C200610121805A.XY.BS22
# Working on    C200610121805A.XZ.BAGL
#   step completed in 1.91e+00 s
# Working on    C200610121805A.XZ.BARK
#   step completed in 2.17e+00 s
# Working on    C200610121805A.XZ.BARN
#   step completed in 2.09e+00 s
# Working on    C200610121805A.XZ.BERG
#   step completed in 1.84e+00 s
# Working on    C200610121805A.XZ.BGLC
#   step completed in 1.91e+00 s
# Working on    C200610121805A.XZ.GOAT
# Working on    C200610121805A.XZ.GRIN
# Working on    C200610121805A.XZ.GRNC
#   step completed in 2.10e+00 s
# Working on    C200610121805A.XZ.ISLE
#   step completed in 2.24e+00 s
# Working on    C200610121805A.XZ.KHIT
#   step completed in 2.04e+00 s
# Working on    C200610121805A.XZ.KIAG
#   step completed in 1.86e+00 s
# Working on    C200610121805A.XZ.KULT
# Working on    C200610121805A.XZ.LOGN
#   step completed in 1.81e+00 s
# Working on    C200610121805A.XZ.MCAR
#   step completed in 1.92e+00 s
# Working on    C200610121805A.XZ.MESA
#   step completed in 2.16e+00 s
# Working on    C200610121805A.XZ.NICH
#   step completed in 2.07e+00 s
# Working on    C200610121805A.XZ.PTPK
#   step completed in 1.92e+00 s
# Working on    C200610121805A.XZ.RKAV
#   step completed in 1.94e+00 s
# Working on    C200610121805A.XZ.SAMH
#   step completed in 2.47e+00 s
# Working on    C200610121805A.XZ.SUCK
#   step completed in 2.04e+00 s
# Working on    C200610121805A.XZ.TABL
#   step completed in 1.85e+00 s
# Working on    C200610121805A.XZ.VRDI
#   step completed in 1.80e+00 s
# Working on    C200610121805A.YV.BING
#   step completed in 2.45e+00 s
# Working on    C200610121805A.YV.HOPJ
#   step completed in 1.85e+00 s
# Working on    C200610121805A.YV.NANC
#   step completed in 1.95e+00 s
# Working on    C200610121805A.YV.PORT
#   step completed in 2.03e+00 s
# Working on    C200610131347A.C.CLCH
# Working on    C200610131347A.G.PEL
#   step completed in 2.10e+00 s
# Working on    C200610131347A.IU.LCO
#   step completed in 2.32e+00 s
# Working on    C200610131347A.IU.TRQA
#   step completed in 3.67e+00 s
# Working on    C200610151707A.G.MPG
#   step completed in 2.15e+00 s
# Working on    C200610151707A.II.ASCN
#   step completed in 4.27e+00 s
# Working on    C200610151707A.II.SHEL
#   step completed in 1.93e+00 s
# Working on    C200610151707A.IU.PTGA
# Working on    C200610151707A.IU.SAML
#   step completed in 3.68e+00 s
# Working on    C200610151714A.G.MPG
#   step completed in 1.95e+00 s
# Working on    C200610151714A.II.ASCN
#   step completed in 4.14e+00 s
# Working on    C200610151714A.II.SHEL
#   step completed in 2.04e+00 s
# Working on    C200610151714A.IU.PTGA
# Working on    C200610151714A.IU.SAML
#   step completed in 3.35e+00 s
# Working on    C200610201048A.IU.ADK
# Working on    C200610201048A.IU.JOHN
# Working on    C200610201048A.IU.MIDW
#   step completed in 2.04e+00 s
# Working on    C200610262254A.IU.ADK
# Working on    C200610262254A.IU.JOHN
# Working on    C200610262254A.IU.MIDW
#   step completed in 2.14e+00 s
# Working on    C200611122127A.C.CLCH
# Working on    C200611122127A.G.PEL
#   step completed in 2.30e+00 s
# Working on    C200611122127A.IU.LCO
#   step completed in 2.44e+00 s
# Working on    C200611122127A.IU.TRQA
#   step completed in 4.03e+00 s
# Working on    C200611122127A.YJ.CAL01
# Working on    C200611122127A.YJ.CTS01
# Working on    C200611122127A.YJ.IMG01
# Working on    C200611122127A.YJ.MEL01
# Working on    C200611122127A.YJ.PYU01
# Working on    C200611122127A.YJ.RCS01
# Working on    C200611122127A.YJ.RMB02
# Working on    C200611122127A.YJ.VMG01
# Working on    M200611151114A.C.CLCH
# Working on    M200611151114A.G.PEL
#   step completed in 1.93e+00 s
# Working on    M200611151114A.IU.LCO
#   step completed in 2.38e+00 s
# Working on    M200611151114A.IU.TRQA
#   step completed in 3.96e+00 s
# Working on    C200611151140A.C.CLCH
# Working on    C200611151140A.G.PEL
#   step completed in 2.14e+00 s
# Working on    C200611151140A.IU.LCO
#   step completed in 2.16e+00 s
# Working on    C200611151140A.IU.TRQA
#   step completed in 3.30e+00 s
# Working on    C200611151925A.C.CLCH
# Working on    C200611151925A.G.PEL
#   step completed in 2.06e+00 s
# Working on    C200611151925A.IU.LCO
#   step completed in 2.03e+00 s
# Working on    C200611151925A.IU.TRQA
#   step completed in 3.69e+00 s
# Working on    C200611151925A.YJ.RCS01
# Working on    C200611151925A.YJ.RMB02
# Working on    C200611152122A.C.CLCH
# Working on    C200611152122A.G.PEL
#   step completed in 1.98e+00 s
# Working on    C200611152122A.IU.LCO
#   step completed in 2.13e+00 s
# Working on    C200611152122A.IU.TRQA
#   step completed in 3.36e+00 s
# Working on    C200611152122A.YJ.RCS01
# Working on    C200611160620A.C.CLCH
# Working on    C200611160620A.G.PEL
#   step completed in 3.31e+00 s
# Working on    C200611160620A.IU.LCO
#   step completed in 2.29e+00 s
# Working on    C200611160620A.IU.TRQA
#   step completed in 3.91e+00 s
# Working on    C200611191857A.GE.CART
#   step completed in 2.19e+00 s
# Working on    C200611191857A.GE.CEU
# Working on    C200611191857A.GE.MAHO
# Working on    C200611191857A.GE.MELI
#   step completed in 1.98e+00 s
# Working on    C200611191857A.GE.MTE
# Working on    C200611191857A.GE.PVLZ
# Working on    C200611191857A.GE.SFS
#   step completed in 2.00e+00 s
# Working on    C200611191857A.IU.PAB
#   step completed in 1.96e+00 s
# Working on    C200611191857A.LX.MORF
# Working on    C200611191857A.MN.RTC
#   step completed in 2.15e+00 s
# Working on    C200611191857A.PM.PESTR
# Working on    C200611301133A.CN.SADO
#   step completed in 2.17e+00 s
# Working on    C200611301133A.II.CMLA
# Working on    C200611301133A.IU.DWPF
#   step completed in 2.10e+00 s
# Working on    C200611301133A.IU.HRV
#   step completed in 2.68e+00 s
# Working on    C200611301133A.IU.SSPA
#   step completed in 4.23e+00 s
# Working on    C200611301133A.IU.WCI
#   step completed in 2.41e+00 s
# Working on    C200611301133A.IU.WVT
#   step completed in 2.18e+00 s
# Working on    C200611301133A.LD.PAL
#   step completed in 2.44e+00 s
# Working on    C200611301133A.LI.LTL
#   step completed in 2.42e+00 s
# Working on    C200611301133A.NM.BLO
#   step completed in 2.41e+00 s
# Working on    C200611301133A.NM.MPH
#   step completed in 2.22e+00 s
# Working on    C200611301133A.NM.PLAL
# Working on    C200611301133A.NM.USIN
#   step completed in 2.06e+00 s
# Working on    C200611301133A.NM.UTMT
#   step completed in 3.35e+00 s
# Working on    C200611301133A.US.ACSO
# Working on    C200611301133A.US.BINY
#   step completed in 2.36e+00 s
# Working on    C200611301133A.US.BLA
#   step completed in 2.13e+00 s
# Working on    C200611301133A.US.BRAL
#   step completed in 1.87e+00 s
# Working on    C200611301133A.US.CBN
#   step completed in 2.26e+00 s
# Working on    C200611301133A.US.CNNC
#   step completed in 2.85e+00 s
# Working on    C200611301133A.US.ERPA
# Working on    C200611301133A.US.GOGA
#   step completed in 1.80e+00 s
# Working on    C200611301133A.US.LBNH
# Working on    C200611301133A.US.LONY
#   step completed in 1.90e+00 s
# Working on    C200611301133A.US.LRAL
#   step completed in 2.30e+00 s
# Working on    C200611301133A.US.MCWV
#   step completed in 2.08e+00 s
# Working on    C200611301133A.US.MYNC
# Working on    C200611301133A.US.NCB
#   step completed in 2.44e+00 s
# Working on    C200611301133A.US.NHSC
#   step completed in 2.22e+00 s
# Working on    C200611301133A.US.OXF
#   step completed in 2.50e+00 s
# Working on    C200611301133A.US.TZTN
#   step completed in 1.91e+00 s
# Working on    C200611302120A.AT.SIT
# Working on    C200611302120A.DK.BSD
# Working on    C200611302120A.DK.MUD
# Working on    C200611302120A.GE.DAG
# Working on    C200611302120A.GE.HLG
#   step completed in 2.46e+00 s
# Working on    C200611302120A.GE.KBS
#   step completed in 3.40e+00 s
# Working on    C200611302120A.GE.RGN
#   step completed in 1.83e+00 s
# Working on    C200611302120A.GE.SUMG
#   step completed in 2.32e+00 s
# Working on    C200611302120A.II.ALE
#   step completed in 4.05e+00 s
# Working on    C200611302120A.II.BORG
#   step completed in 3.93e+00 s
# Working on    C200611302120A.II.ESK
#   step completed in 2.34e+00 s
# Working on    C200611302120A.II.FFC
#   step completed in 2.10e+00 s
# Working on    C200611302120A.IU.KBS
#   step completed in 3.80e+00 s
# Working on    C200611302120A.IU.KEV
#   step completed in 3.81e+00 s
# Working on    C200611302120A.IU.KONO
#   step completed in 3.86e+00 s
# Working on    C200611302120A.US.WRAK
#   step completed in 3.40e+00 s
# Working on    C200612071910A.C.CLCH
# Working on    C200612071910A.G.PEL
#   step completed in 1.94e+00 s
# Working on    C200612071910A.IU.LCO
#   step completed in 1.99e+00 s
# Working on    C200612071910A.IU.TRQA
#   step completed in 3.90e+00 s
# Working on    C200612171251A.CN.SADO
#   step completed in 2.34e+00 s
# Working on    C200612171251A.II.CMLA
# Working on    C200612171251A.IU.DWPF
#   step completed in 2.14e+00 s
# Working on    C200612171251A.IU.HRV
#   step completed in 2.43e+00 s
# Working on    C200612171251A.IU.SSPA
#   step completed in 3.51e+00 s
# Working on    C200612171251A.IU.WCI
#   step completed in 2.07e+00 s
# Working on    C200612171251A.IU.WVT
#   step completed in 2.32e+00 s
# Working on    C200612171251A.LD.PAL
# Working on    C200612171251A.LI.LTL
#   step completed in 2.70e+00 s
# Working on    C200612171251A.NM.PLAL
# Working on    C200612171251A.US.ACSO
#   step completed in 2.15e+00 s
# Working on    C200612171251A.US.BINY
#   step completed in 2.22e+00 s
# Working on    C200612171251A.US.BLA
#   step completed in 2.05e+00 s
# Working on    C200612171251A.US.BRAL
#   step completed in 1.83e+00 s
# Working on    C200612171251A.US.CBN
#   step completed in 2.32e+00 s
# Working on    C200612171251A.US.CNNC
#   step completed in 1.78e+00 s
# Working on    C200612171251A.US.ERPA
# Working on    C200612171251A.US.GOGA
#   step completed in 1.75e+00 s
# Working on    C200612171251A.US.LBNH
#   step completed in 2.12e+00 s
# Working on    C200612171251A.US.LONY
#   step completed in 1.86e+00 s
# Working on    C200612171251A.US.LRAL
#   step completed in 2.22e+00 s
# Working on    C200612171251A.US.MCWV
#   step completed in 2.38e+00 s
# Working on    C200612171251A.US.MYNC
# Working on    C200612171251A.US.NCB
#   step completed in 1.97e+00 s
# Working on    C200612171251A.US.NHSC
#   step completed in 1.96e+00 s
# Working on    C200612171251A.US.OXF
#   step completed in 2.21e+00 s
# Working on    C200612171251A.US.TZTN
#   step completed in 2.22e+00 s
# Working on    C200612261519A.C.CLCH
# Working on    C200612261519A.G.PEL
#   step completed in 2.00e+00 s
# Working on    C200612261519A.IU.LCO
#   step completed in 2.35e+00 s
# Working on    C200612261519A.IU.TRQA
#   step completed in 3.72e+00 s
# Working on    C200612261519A.YJ.IMG01
# Working on    C200612261519A.YJ.MEL01
# Working on    C200612261519A.YJ.RMB02
# Working on    C200701130423A.C.CLCH
# Working on    C200701130423A.G.PEL
#   step completed in 2.08e+00 s
# Working on    C200701130423A.IU.LCO
#   step completed in 2.33e+00 s
# Working on    C200701130423A.IU.TRQA
#   step completed in 3.47e+00 s
# Working on    C200701131737A.C.CLCH
# Working on    C200701131737A.G.PEL
#   step completed in 2.05e+00 s
# Working on    C200701131737A.IU.TRQA
#   step completed in 3.82e+00 s
# Working on    C200701131737A.Y3.RMB01
#   step completed in 2.00e+00 s
# Working on    C200701131737A.Y3.RMB02
# Working on    C200701200621A.AT.PMR
# Working on    C200701200621A.AT.SIT
# Working on    C200701200621A.CN.INK
#   step completed in 2.54e+00 s
# Working on    C200701200621A.II.KDAK
# Working on    C200701200621A.IU.COLA
#   step completed in 3.75e+00 s
# Working on    C200701200621A.US.EGAK
#   step completed in 1.73e+00 s
# Working on    C200701200621A.XR.BMQ
#   step completed in 1.91e+00 s
# Working on    C200701200621A.XR.CBM
#   step completed in 1.77e+00 s
# Working on    C200701200621A.XR.CHS
#   step completed in 1.79e+00 s
# Working on    C200701200621A.XR.FRB
#   step completed in 2.13e+00 s
# Working on    C200701200621A.XR.GBN
#   step completed in 1.81e+00 s
# Working on    C200701200621A.XR.GTM
#   step completed in 1.83e+00 s
# Working on    C200701200621A.XR.ICT
#   step completed in 1.85e+00 s
# Working on    C200701200621A.XR.LMW
#   step completed in 1.96e+00 s
# Working on    C200701200621A.XR.LVG
# Working on    C200701200621A.XR.NOM
#   step completed in 1.71e+00 s
# Working on    C200701200621A.XR.PRB
#   step completed in 1.61e+00 s
# Working on    C200701200621A.XR.RBY
#   step completed in 1.86e+00 s
# Working on    C200701200621A.XR.SAG
#   step completed in 1.82e+00 s
# Working on    C200701200621A.XR.TFS
#   step completed in 1.89e+00 s
# Working on    C200701200621A.XR.WSM
#   step completed in 1.90e+00 s
# Working on    C200701200621A.XR.YRT
#   step completed in 1.82e+00 s
# Working on    C200701200621A.XZ.BAGL
#   step completed in 1.95e+00 s
# Working on    C200701200621A.XZ.BARK
#   step completed in 2.22e+00 s
# Working on    C200701200621A.XZ.BARN
#   step completed in 2.19e+00 s
# Working on    C200701200621A.XZ.BERG
#   step completed in 2.30e+00 s
# Working on    C200701200621A.XZ.BGLC
# Working on    C200701200621A.XZ.GOAT
# Working on    C200701200621A.XZ.GRIN
#   step completed in 1.97e+00 s
# Working on    C200701200621A.XZ.GRNC
#   step completed in 2.44e+00 s
# Working on    C200701200621A.XZ.ISLE
#   step completed in 3.15e+00 s
# Working on    C200701200621A.XZ.KHIT
#   step completed in 1.85e+00 s
# Working on    C200701200621A.XZ.KIAG
#   step completed in 1.77e+00 s
# Working on    C200701200621A.XZ.KULT
#   step completed in 2.15e+00 s
# Working on    C200701200621A.XZ.LOGN
#   step completed in 2.35e+00 s
# Working on    C200701200621A.XZ.MCAR
# Working on    C200701200621A.XZ.MESA
# Working on    C200701200621A.XZ.NICH
#   step completed in 2.20e+00 s
# Working on    C200701200621A.XZ.PTPK
#   step completed in 2.29e+00 s
# Working on    C200701200621A.XZ.RKAV
#   step completed in 2.01e+00 s
# Working on    C200701200621A.XZ.SAMH
#   step completed in 2.79e+00 s
# Working on    C200701200621A.XZ.SUCK
#   step completed in 2.20e+00 s
# Working on    C200701200621A.XZ.TABL
#   step completed in 2.07e+00 s
# Working on    C200701200621A.XZ.VRDI
#   step completed in 1.89e+00 s
# Working on    C200701200621A.YV.BING
#   step completed in 2.02e+00 s
# Working on    C200701200621A.YV.HOPJ
#   step completed in 1.86e+00 s
# Working on    C200701200621A.YV.NANC
#   step completed in 1.62e+00 s
# Working on    C200701200621A.YV.PORT
#   step completed in 1.73e+00 s
# Working on    C200701302137A.IU.SAML
# Working on    C200701310315A.II.CMLA
# Working on    C200701310315A.IU.WCI
#   step completed in 2.13e+00 s
# Working on    C200701310315A.IU.WVT
#   step completed in 2.31e+00 s
# Working on    C200701310315A.LI.LTL
#   step completed in 2.47e+00 s
# Working on    C200701310315A.NM.PLAL
# Working on    C200701310315A.US.ACSO
#   step completed in 1.99e+00 s
# Working on    C200701310315A.US.BLA
#   step completed in 2.36e+00 s
# Working on    C200701310315A.US.BRAL
#   step completed in 2.12e+00 s
# Working on    C200701310315A.US.CNNC
#   step completed in 1.96e+00 s
# Working on    C200701310315A.US.ERPA
# Working on    C200701310315A.US.GOGA
#   step completed in 1.41e+00 s
# Working on    C200701310315A.US.LRAL
#   step completed in 2.42e+00 s
# Working on    C200701310315A.US.MCWV
#   step completed in 2.08e+00 s
# Working on    C200701310315A.US.NHSC
#   step completed in 2.84e+00 s
# Working on    C200701310315A.US.OXF
#   step completed in 2.32e+00 s
# Working on    C200701310315A.US.TZTN
#   step completed in 2.24e+00 s
# Working on    C200702042056A.5A.LEOS
#   step completed in 1.90e+00 s
# Working on    C200702042056A.5A.NOAA
#   step completed in 2.22e+00 s
# Working on    C200702042056A.5A.SAVE
#   step completed in 2.16e+00 s
# Working on    C200702042056A.5A.SAVW
# Working on    C200702042056A.II.MSVF
# Working on    C200702042056A.IU.AFI
#   step completed in 3.89e+00 s
# Working on    C200702042056A.IU.FUNA
#   step completed in 2.98e+00 s
# Working on    C200702042117A.AT.SIT
# Working on    C200702042117A.GE.DAG
# Working on    C200702042117A.GE.KBS
# Working on    C200702042117A.GE.SUMG
#   step completed in 2.13e+00 s
# Working on    C200702042117A.II.ALE
#   step completed in 4.51e+00 s
# Working on    C200702042117A.II.BORG
#   step completed in 4.47e+00 s
# Working on    C200702042117A.II.LVZ
#   step completed in 2.49e+00 s
# Working on    C200702042117A.IU.KBS
#   step completed in 3.71e+00 s
# Working on    C200702042117A.IU.KEV
#   step completed in 3.86e+00 s
# Working on    C200702042117A.IU.KONO
#   step completed in 3.76e+00 s
# Working on    C200702042117A.US.WRAK
#   step completed in 3.26e+00 s
# Working on    C200702120208A.G.MPG
#   step completed in 2.44e+00 s
# Working on    C200702121035A.II.RPN
#   step completed in 4.53e+00 s
# Working on    C200702121035A.IU.RAR
#   step completed in 3.63e+00 s
# Working on    C200702140129A.AT.PMR
# Working on    C200702140129A.CN.FRB
#   step completed in 2.52e+00 s
# Working on    C200702140129A.CN.INK
#   step completed in 2.49e+00 s
# Working on    C200702140129A.CN.RES
#   step completed in 2.62e+00 s
# Working on    C200702140129A.GE.KWP
# Working on    C200702140129A.GE.SFJD
# Working on    C200702140129A.GE.SUMG
#   step completed in 1.93e+00 s
# Working on    C200702140129A.II.ALE
#   step completed in 4.32e+00 s
# Working on    C200702140129A.II.CMLA
# Working on    C200702140129A.IU.BILL
#   step completed in 2.54e+00 s
# Working on    C200702140129A.IU.COLA
#   step completed in 4.01e+00 s
# Working on    C200702140129A.IU.KIEV
#   step completed in 2.33e+00 s
# Working on    C200702140129A.IU.SFJD
#   step completed in 3.90e+00 s
# Working on    C200702140129A.PL.KWP
# Working on    C200702140129A.US.EGAK
#   step completed in 1.81e+00 s
# Working on    C200702140129A.XR.BMQ
#   step completed in 1.96e+00 s
# Working on    C200702140129A.XR.CBM
#   step completed in 1.79e+00 s
# Working on    C200702140129A.XR.CHS
#   step completed in 2.04e+00 s
# Working on    C200702140129A.XR.FRB
# Working on    C200702140129A.XR.GBN
#   step completed in 1.88e+00 s
# Working on    C200702140129A.XR.GTM
#   step completed in 1.88e+00 s
# Working on    C200702140129A.XR.ICT
#   step completed in 2.06e+00 s
# Working on    C200702140129A.XR.LMW
#   step completed in 1.83e+00 s
# Working on    C200702140129A.XR.LVG
# Working on    C200702140129A.XR.NOM
#   step completed in 1.84e+00 s
# Working on    C200702140129A.XR.PRB
#   step completed in 1.96e+00 s
# Working on    C200702140129A.XR.RBY
#   step completed in 1.74e+00 s
# Working on    C200702140129A.XR.SAG
#   step completed in 1.85e+00 s
# Working on    C200702140129A.XR.TFS
#   step completed in 1.80e+00 s
# Working on    C200702140129A.XR.WSM
#   step completed in 1.88e+00 s
# Working on    C200702140129A.XR.YRT
#   step completed in 2.03e+00 s
# Working on    C200702140129A.YV.BING
#   step completed in 1.94e+00 s
# Working on    C200702140129A.YV.HOPJ
#   step completed in 2.25e+00 s
# Working on    C200702140129A.YV.NANC
#   step completed in 2.15e+00 s
# Working on    C200702140129A.YV.PORT
#   step completed in 1.80e+00 s
# Working on    C200702170002A.C.CLCH
# Working on    C200702170002A.G.PEL
#   step completed in 2.34e+00 s
# Working on    C200702170002A.GE.LVC
# Working on    C200702170002A.IU.LCO
#   step completed in 2.01e+00 s
# Working on    C200702170002A.IU.LVC
# Working on    C200702170002A.IU.TRQA
# Working on    C200702240236A.IU.MIDW
#   step completed in 2.20e+00 s
# Working on    C200702240236A.IU.WAKE
# Working on    C200702282313A.AT.PMR
# Working on    C200702282313A.AT.SIT
# Working on    C200702282313A.CN.INK
#   step completed in 2.33e+00 s
# Working on    C200702282313A.II.KDAK
#   step completed in 4.47e+00 s
# Working on    C200702282313A.IU.COLA
#   step completed in 3.69e+00 s
# Working on    C200702282313A.US.EGAK
#   step completed in 2.13e+00 s
# Working on    C200702282313A.XR.BMQ
#   step completed in 1.67e+00 s
# Working on    C200702282313A.XR.CBM
#   step completed in 1.73e+00 s
# Working on    C200702282313A.XR.CHS
#   step completed in 1.99e+00 s
# Working on    C200702282313A.XR.FRB
# Working on    C200702282313A.XR.GBN
#   step completed in 1.88e+00 s
# Working on    C200702282313A.XR.GTM
#   step completed in 2.12e+00 s
# Working on    C200702282313A.XR.ICT
#   step completed in 2.05e+00 s
# Working on    C200702282313A.XR.LMW
#   step completed in 2.09e+00 s
# Working on    C200702282313A.XR.LVG
# Working on    C200702282313A.XR.NOM
#   step completed in 2.14e+00 s
# Working on    C200702282313A.XR.PRB
#   step completed in 1.84e+00 s
# Working on    C200702282313A.XR.RBY
#   step completed in 1.83e+00 s
# Working on    C200702282313A.XR.SAG
#   step completed in 1.93e+00 s
# Working on    C200702282313A.XR.TFS
#   step completed in 1.92e+00 s
# Working on    C200702282313A.XR.WSM
#   step completed in 2.00e+00 s
# Working on    C200702282313A.XR.YRT
#   step completed in 1.76e+00 s
# Working on    C200702282313A.XZ.BAGL
#   step completed in 2.06e+00 s
# Working on    C200702282313A.XZ.BARK
#   step completed in 2.07e+00 s
# Working on    C200702282313A.XZ.BARN
#   step completed in 2.16e+00 s
# Working on    C200702282313A.XZ.BERG
#   step completed in 2.02e+00 s
# Working on    C200702282313A.XZ.BGLC
#   step completed in 2.00e+00 s
# Working on    C200702282313A.XZ.GOAT
# Working on    C200702282313A.XZ.GRIN
#   step completed in 1.89e+00 s
# Working on    C200702282313A.XZ.GRNC
#   step completed in 2.04e+00 s
# Working on    C200702282313A.XZ.ISLE
#   step completed in 1.71e+00 s
# Working on    C200702282313A.XZ.KHIT
#   step completed in 2.09e+00 s
# Working on    C200702282313A.XZ.KIAG
#   step completed in 1.89e+00 s
# Working on    C200702282313A.XZ.KULT
#   step completed in 2.04e+00 s
# Working on    C200702282313A.XZ.LOGN
#   step completed in 1.72e+00 s
# Working on    C200702282313A.XZ.MCAR
#   step completed in 2.04e+00 s
# Working on    C200702282313A.XZ.MESA
#   step completed in 1.97e+00 s
# Working on    C200702282313A.XZ.NICH
#   step completed in 2.16e+00 s
# Working on    C200702282313A.XZ.PTPK
#   step completed in 2.07e+00 s
# Working on    C200702282313A.XZ.RKAV
#   step completed in 2.07e+00 s
# Working on    C200702282313A.XZ.SAMH
#   step completed in 2.04e+00 s
# Working on    C200702282313A.XZ.SUCK
#   step completed in 3.04e+00 s
# Working on    C200702282313A.XZ.TABL
#   step completed in 1.97e+00 s
# Working on    C200702282313A.XZ.VRDI
#   step completed in 1.85e+00 s
# Working on    C200702282313A.YV.BING
#   step completed in 1.93e+00 s
# Working on    C200702282313A.YV.HOPJ
#   step completed in 1.87e+00 s
# Working on    C200702282313A.YV.NANC
#   step completed in 2.62e+00 s
# Working on    C200702282313A.YV.PORT
#   step completed in 2.17e+00 s
# Working on    C200703012311A.G.NOUC
#   step completed in 1.97e+00 s
# Working on    C200703012311A.G.PPT
#   step completed in 2.18e+00 s
# Working on    C200703012311A.IU.PTCN
#   step completed in 2.21e+00 s
# Working on    C200703012311A.IU.XMAS
# Working on    C200703081114A.AT.PMR
# Working on    C200703081114A.IU.COLA
#   step completed in 4.08e+00 s
# Working on    C200703081114A.US.EGAK
#   step completed in 1.91e+00 s
# Working on    C200703081114A.XR.RBY
#   step completed in 1.87e+00 s
# Working on    C200703081114A.XZ.BAGL
#   step completed in 2.16e+00 s
# Working on    C200703081114A.XZ.BARK
#   step completed in 2.37e+00 s
# Working on    C200703081114A.XZ.BARN
#   step completed in 2.21e+00 s
# Working on    C200703081114A.XZ.BERG
#   step completed in 1.97e+00 s
# Working on    C200703081114A.XZ.BGLC
#   step completed in 1.89e+00 s
# Working on    C200703081114A.XZ.GOAT
# Working on    C200703081114A.XZ.GRIN
#   step completed in 2.31e+00 s
# Working on    C200703081114A.XZ.GRNC
#   step completed in 2.16e+00 s
# Working on    C200703081114A.XZ.ISLE
#   step completed in 1.14e+00 s
# Working on    C200703081114A.XZ.KHIT
#   step completed in 2.14e+00 s
# Working on    C200703081114A.XZ.KIAG
#   step completed in 2.14e+00 s
# Working on    C200703081114A.XZ.KULT
#   step completed in 2.07e+00 s
# Working on    C200703081114A.XZ.LOGN
#   step completed in 1.73e+00 s
# Working on    C200703081114A.XZ.MCAR
#   step completed in 1.64e+00 s
# Working on    C200703081114A.XZ.MESA
#   step completed in 2.05e+00 s
# Working on    C200703081114A.XZ.NICH
#   step completed in 2.06e+00 s
# Working on    C200703081114A.XZ.PTPK
#   step completed in 2.03e+00 s
# Working on    C200703081114A.XZ.RKAV
#   step completed in 2.15e+00 s
# Working on    C200703081114A.XZ.SAMH
#   step completed in 1.99e+00 s
# Working on    C200703081114A.XZ.SUCK
#   step completed in 2.14e+00 s
# Working on    C200703081114A.XZ.TABL
#   step completed in 2.05e+00 s
# Working on    C200703081114A.XZ.VRDI
#   step completed in 2.14e+00 s
# Working on    C200703081114A.YV.BING
#   step completed in 1.94e+00 s
# Working on    C200703081114A.YV.HOPJ
#   step completed in 1.75e+00 s
# Working on    C200703081114A.YV.NANC
#   step completed in 1.92e+00 s
# Working on    C200703081114A.YV.PORT
#   step completed in 1.87e+00 s
# Working on    C200703102112A.II.EFI
# Working on    C200703102112A.IU.TRQA
#   step completed in 3.97e+00 s
# Working on    C200703172243A.IU.MIDW
#   step completed in 2.28e+00 s
# Working on    C200703172243A.IU.TARA
# Working on    C200703172243A.IU.WAKE
# Working on    C200703180211A.IU.MIDW
#   step completed in 2.18e+00 s
# Working on    C200703180211A.IU.TARA
# Working on    C200703180211A.IU.WAKE
# Working on    C200703250041A.GE.LVC
# Working on    C200703250041A.IU.LVC
# Working on    C200703311249A.AT.SIT
# Working on    C200703311249A.GE.DAG
# Working on    C200703311249A.GE.KBS
# Working on    C200703311249A.GE.SUMG
#   step completed in 2.06e+00 s
# Working on    C200703311249A.II.ALE
#   step completed in 4.73e+00 s
# Working on    C200703311249A.II.BORG
#   step completed in 4.20e+00 s
# Working on    C200703311249A.II.LVZ
#   step completed in 2.82e+00 s
# Working on    C200703311249A.IU.KBS
#   step completed in 3.86e+00 s
# Working on    C200703311249A.IU.KEV
#   step completed in 3.87e+00 s
# Working on    C200703311249A.IU.KONO
#   step completed in 4.00e+00 s
# Working on    C200703311249A.US.WRAK
#   step completed in 3.30e+00 s
# Working on    C200704012039A.CU.BBGH
#   step completed in 2.13e+00 s
# Working on    C200704012039A.CU.GRGR
#   step completed in 1.85e+00 s
# Working on    C200704012039A.G.FDF
#   step completed in 1.72e+00 s
# Working on    C200704012111A.CU.BBGH
#   step completed in 1.86e+00 s
# Working on    C200704012111A.CU.GRGR
#   step completed in 1.54e+00 s
# Working on    C200704012111A.G.FDF
#   step completed in 1.70e+00 s
# Working on    C200704020249A.AT.SIT
# Working on    C200704020249A.CN.BBB
#   step completed in 2.35e+00 s
# Working on    C200704020249A.CN.DRLN
#   step completed in 2.67e+00 s
# Working on    C200704020249A.CN.FRB
#   step completed in 2.04e+00 s
# Working on    C200704020249A.CN.LLLB
#   step completed in 2.29e+00 s
# Working on    C200704020249A.CN.SCHQ
#   step completed in 2.09e+00 s
# Working on    C200704020249A.CN.ULM
#   step completed in 2.09e+00 s
# Working on    C200704020249A.CN.YKW1
#   step completed in 2.39e+00 s
# Working on    C200704020249A.CN.YKW2
#   step completed in 2.07e+00 s
# Working on    C200704020249A.CN.YKW3
#   step completed in 2.06e+00 s
# Working on    C200704020249A.CN.YKW4
#   step completed in 1.94e+00 s
# Working on    C200704020249A.GE.SFJD
# Working on    C200704020249A.II.FFC
#   step completed in 2.40e+00 s
# Working on    C200704020249A.IU.BILL
#   step completed in 2.48e+00 s
# Working on    C200704020249A.IU.MA2
#   step completed in 2.27e+00 s
# Working on    C200704020249A.IU.PET
#   step completed in 2.25e+00 s
# Working on    C200704020249A.IU.SFJD
#   step completed in 3.66e+00 s
# Working on    C200704020249A.IU.TIXI
#   step completed in 2.23e+00 s
# Working on    C200704020249A.IU.YAK
#   step completed in 2.44e+00 s
# Working on    C200704020249A.LI.LTH
#   step completed in 2.69e+00 s
# Working on    C200704020249A.PB.B001
#   step completed in 2.09e+00 s
# Working on    C200704020249A.PB.B003
#   step completed in 1.92e+00 s
# Working on    C200704020249A.PB.B004
#   step completed in 1.86e+00 s
# Working on    C200704020249A.PB.B005
#   step completed in 1.82e+00 s
# Working on    C200704020249A.PB.B006
#   step completed in 1.83e+00 s
# Working on    C200704020249A.PB.B007
#   step completed in 1.63e+00 s
# Working on    C200704020249A.PB.B009
#   step completed in 1.86e+00 s
# Working on    C200704020249A.PB.B010
#   step completed in 1.80e+00 s
# Working on    C200704020249A.PB.B011
#   step completed in 1.94e+00 s
# Working on    C200704020249A.PB.B012
#   step completed in 2.15e+00 s
# Working on    C200704020249A.PB.B013
# Working on    C200704020249A.PB.B018
#   step completed in 1.80e+00 s
# Working on    C200704020249A.PB.B022
#   step completed in 1.59e+00 s
# Working on    C200704020249A.PB.B024
#   step completed in 1.74e+00 s
# Working on    C200704020249A.TA.A04A
#   step completed in 1.94e+00 s
# Working on    C200704020249A.TA.A05A
#   step completed in 2.02e+00 s
# Working on    C200704020249A.TA.A06A
#   step completed in 1.86e+00 s
# Working on    C200704020249A.TA.A07A
#   step completed in 2.07e+00 s
# Working on    C200704020249A.TA.A08A
#   step completed in 2.01e+00 s
# Working on    C200704020249A.TA.A09A
#   step completed in 1.82e+00 s
# Working on    C200704020249A.TA.A10A
#   step completed in 1.75e+00 s
# Working on    C200704020249A.TA.A11A
#   step completed in 1.64e+00 s
# Working on    C200704020249A.TA.A12A
#   step completed in 2.04e+00 s
# Working on    C200704020249A.TA.A13A
#   step completed in 1.78e+00 s
# Working on    C200704020249A.TA.B04A
#   step completed in 1.87e+00 s
# Working on    C200704020249A.TA.B05A
#   step completed in 1.81e+00 s
# Working on    C200704020249A.TA.B06A
#   step completed in 1.81e+00 s
# Working on    C200704020249A.TA.B07A
#   step completed in 2.08e+00 s
# Working on    C200704020249A.TA.B08A
#   step completed in 2.47e+00 s
# Working on    C200704020249A.TA.B09A
#   step completed in 1.81e+00 s
# Working on    C200704020249A.TA.B10A
#   step completed in 1.75e+00 s
# Working on    C200704020249A.TA.B11A
#   step completed in 2.47e+00 s
# Working on    C200704020249A.TA.B12A
#   step completed in 1.23e+02 s
# Working on    C200704020249A.TA.B13A
#   step completed in 2.45e+00 s
# Working on    C200704020249A.TA.C03A
#   step completed in 1.95e+00 s
# Working on    C200704020249A.TA.C04A
#   step completed in 1.73e+00 s
# Working on    C200704020249A.TA.C05A
#   step completed in 1.95e+00 s
# Working on    C200704020249A.TA.C06A
#   step completed in 1.63e+00 s
# Working on    C200704020249A.TA.C07A
#   step completed in 2.23e+00 s
# Working on    C200704020249A.TA.C08A
#   step completed in 1.73e+00 s
# Working on    C200704020249A.TA.C09A
#   step completed in 1.83e+00 s
# Working on    C200704020249A.TA.C10A
#   step completed in 1.76e+00 s
# Working on    C200704020249A.TA.C13A
#   step completed in 1.81e+00 s
# Working on    C200704020249A.TA.C14A
#   step completed in 1.75e+00 s
# Working on    C200704020249A.TA.D03A
#   step completed in 1.81e+00 s
# Working on    C200704020249A.TA.D04A
#   step completed in 1.90e+00 s
# Working on    C200704020249A.TA.D05A
#   step completed in 1.78e+00 s
# Working on    C200704020249A.TA.D06A
#   step completed in 1.73e+00 s
# Working on    C200704020249A.TA.D07A
#   step completed in 2.15e+00 s
# Working on    C200704020249A.TA.D08A
#   step completed in 2.14e+00 s
# Working on    C200704020249A.TA.D09A
#   step completed in 2.08e+00 s
# Working on    C200704020249A.TA.D10A
#   step completed in 1.87e+00 s
# Working on    C200704020249A.TA.D11A
#   step completed in 1.94e+00 s
# Working on    C200704020249A.TA.D12A
#   step completed in 1.85e+00 s
# Working on    C200704020249A.TA.D13A
#   step completed in 1.85e+00 s
# Working on    C200704020249A.TA.D14A
#   step completed in 1.95e+00 s
# Working on    C200704020249A.TA.D15A
#   step completed in 1.74e+00 s
# Working on    C200704020249A.TA.E03A
#   step completed in 1.83e+00 s
# Working on    C200704020249A.TA.E04A
#   step completed in 2.06e+00 s
# Working on    C200704020249A.TA.E05A
#   step completed in 1.83e+00 s
# Working on    C200704020249A.TA.E06A
#   step completed in 1.75e+00 s
# Working on    C200704020249A.TA.E07A
#   step completed in 1.56e+00 s
# Working on    C200704020249A.TA.E08A
#   step completed in 1.74e+00 s
# Working on    C200704020249A.TA.E09A
#   step completed in 2.16e+00 s
# Working on    C200704020249A.TA.E10A
#   step completed in 1.68e+00 s
# Working on    C200704020249A.TA.E11A
#   step completed in 1.93e+00 s
# Working on    C200704020249A.TA.E13A
#   step completed in 1.84e+00 s
# Working on    C200704020249A.TA.E14A
#   step completed in 1.82e+00 s
# Working on    C200704020249A.TA.E15A
#   step completed in 1.62e+00 s
# Working on    C200704020249A.TA.F03A
#   step completed in 1.96e+00 s
# Working on    C200704020249A.TA.F04A
#   step completed in 1.94e+00 s
# Working on    C200704020249A.TA.F05A
#   step completed in 1.97e+00 s
# Working on    C200704020249A.TA.F06A
#   step completed in 1.89e+00 s
# Working on    C200704020249A.TA.F07A
#   step completed in 1.65e+00 s
# Working on    C200704020249A.TA.F08A
#   step completed in 1.83e+00 s
# Working on    C200704020249A.TA.F09A
#   step completed in 1.78e+00 s
# Working on    C200704020249A.TA.F10A
#   step completed in 1.81e+00 s
# Working on    C200704020249A.TA.F11A
#   step completed in 1.80e+00 s
# Working on    C200704020249A.TA.F12A
#   step completed in 1.88e+00 s
# Working on    C200704020249A.TA.F13A
#   step completed in 1.63e+00 s
# Working on    C200704020249A.TA.F14A
#   step completed in 1.96e+00 s
# Working on    C200704020249A.TA.F15A
#   step completed in 1.76e+00 s
# Working on    C200704020249A.US.AGMN
#   step completed in 1.91e+00 s
# Working on    C200704020249A.US.DGMT
#   step completed in 3.26e+00 s
# Working on    C200704020249A.US.EGMT
#   step completed in 2.10e+00 s
# Working on    C200704020249A.US.HAWA
#   step completed in 2.07e+00 s
# Working on    C200704020249A.US.LAO
#   step completed in 2.28e+00 s
# Working on    C200704020249A.US.MSO
#   step completed in 2.07e+00 s
# Working on    C200704020249A.US.NEW
#   step completed in 3.26e+00 s
# Working on    C200704020249A.US.NLWA
#   step completed in 1.93e+00 s
# Working on    C200704020249A.US.WRAK
#   step completed in 3.09e+00 s
# Working on    C200704020249A.YC.BEZB
#   step completed in 1.76e+00 s
# Working on    C200704020249A.YC.BEZC
#   step completed in 1.93e+00 s
# Working on    C200704020249A.ZG.W11
# Working on    C200704020249A.ZG.W12
# Working on    C200704020249A.ZG.W13
# Working on    C200704020249A.ZG.W14
# Working on    C200704020249A.ZG.W15
# Working on    C200704020249A.ZG.W16
# Working on    C200704020249A.ZG.W17
# Working on    C200704020533A.CU.BBGH
#   step completed in 1.85e+00 s
# Working on    C200704020533A.CU.GRGR
#   step completed in 2.95e+00 s
# Working on    C200704020533A.G.FDF
#   step completed in 1.85e+00 s
# Working on    C200704021049A.CU.BBGH
#   step completed in 2.01e+00 s
# Working on    C200704021049A.CU.GRGR
#   step completed in 2.01e+00 s
# Working on    C200704021049A.G.FDF
#   step completed in 1.84e+00 s
# Working on    C200704021202A.CU.BBGH
#   step completed in 1.93e+00 s
# Working on    C200704021202A.CU.GRGR
#   step completed in 1.79e+00 s
# Working on    C200704021202A.G.FDF
#   step completed in 1.92e+00 s
# Working on    C200704022320A.CU.BBGH
#   step completed in 2.34e+00 s
# Working on    C200704022320A.CU.GRGR
#   step completed in 2.35e+00 s
# Working on    C200704022320A.G.FDF
#   step completed in 2.06e+00 s
# Working on    C200704031204A.CU.BBGH
#   step completed in 2.84e+00 s
# Working on    C200704031204A.CU.GRGR
#   step completed in 1.75e+00 s
# Working on    C200704031204A.G.FDF
#   step completed in 1.97e+00 s
# Working on    C200704040039A.CU.BBGH
#   step completed in 2.06e+00 s
# Working on    C200704040039A.CU.GRGR
#   step completed in 2.15e+00 s
# Working on    C200704040039A.G.FDF
#   step completed in 2.11e+00 s
# Working on    C200704040634A.CU.BBGH
#   step completed in 2.67e+00 s
# Working on    C200704040634A.CU.GRGR
#   step completed in 1.96e+00 s
# Working on    C200704040634A.G.FDF
#   step completed in 1.91e+00 s
# Working on    C200704050356A.II.RPN
#   step completed in 2.85e+00 s
# Working on    C200704050356A.IU.RAO
#   step completed in 2.74e+00 s
# Working on    C200704060554A.AT.SIT
# Working on    C200704060554A.GE.DAG
# Working on    C200704060554A.GE.KBS
# Working on    C200704060554A.GE.SUMG
#   step completed in 2.13e+00 s
# Working on    C200704060554A.II.ALE
#   step completed in 4.13e+00 s
# Working on    C200704060554A.II.BORG
#   step completed in 3.93e+00 s
# Working on    C200704060554A.II.LVZ
# Working on    C200704060554A.IU.KBS
#   step completed in 3.76e+00 s
# Working on    C200704060554A.IU.KEV
#   step completed in 3.98e+00 s
# Working on    C200704060554A.IU.KONO
#   step completed in 3.93e+00 s
# Working on    C200704060554A.US.WRAK
#   step completed in 3.59e+00 s
# Working on    C200704061848A.CU.BBGH
#   step completed in 2.01e+00 s
# Working on    C200704061848A.CU.GRGR
#   step completed in 1.83e+00 s
# Working on    C200704061848A.G.FDF
#   step completed in 1.74e+00 s
# Working on    C200704070709A.II.RPN
#   step completed in 2.70e+00 s
# Working on    C200704070709A.IU.RAO
#   step completed in 2.78e+00 s
# Working on    C200704131824A.AT.PMR
# Working on    C200704131824A.CN.DRLN
#   step completed in 2.14e+00 s
# Working on    C200704131824A.CN.FRB
#   step completed in 2.50e+00 s
# Working on    C200704131824A.CN.INK
#   step completed in 2.43e+00 s
# Working on    C200704131824A.CN.RES
#   step completed in 2.36e+00 s
# Working on    C200704131824A.CN.SCHQ
#   step completed in 2.43e+00 s
# Working on    C200704131824A.CN.YKW1
# Working on    C200704131824A.CN.YKW2
#   step completed in 2.26e+00 s
# Working on    C200704131824A.CN.YKW3
#   step completed in 2.28e+00 s
# Working on    C200704131824A.CN.YKW4
#   step completed in 2.53e+00 s
# Working on    C200704131824A.GE.MHV
# Working on    C200704131824A.GE.PUL
# Working on    C200704131824A.GE.SFJD
# Working on    C200704131824A.GE.SLIT
# Working on    C200704131824A.GE.SUW
#   step completed in 1.62e+00 s
# Working on    C200704131824A.GE.VSU
#   step completed in 2.19e+00 s
# Working on    C200704131824A.II.CMLA
# Working on    C200704131824A.II.KDAK
#   step completed in 4.35e+00 s
# Working on    C200704131824A.II.OBN
#   step completed in 2.50e+00 s
# Working on    C200704131824A.IU.COLA
#   step completed in 4.00e+00 s
# Working on    C200704131824A.IU.SFJD
# Working on    C200704131824A.US.EGAK
#   step completed in 1.86e+00 s
# Working on    C200704131824A.XR.BMQ
#   step completed in 1.90e+00 s
# Working on    C200704131824A.XR.CBM
#   step completed in 1.79e+00 s
# Working on    C200704131824A.XR.CHS
#   step completed in 2.16e+00 s
# Working on    C200704131824A.XR.FRB
#   step completed in 1.92e+00 s
# Working on    C200704131824A.XR.GBN
#   step completed in 2.06e+00 s
# Working on    C200704131824A.XR.GTM
#   step completed in 1.83e+00 s
# Working on    C200704131824A.XR.ICT
#   step completed in 1.85e+00 s
# Working on    C200704131824A.XR.LMW
#   step completed in 2.08e+00 s
# Working on    C200704131824A.XR.LVG
# Working on    C200704131824A.XR.NOM
#   step completed in 1.71e+00 s
# Working on    C200704131824A.XR.PRB
#   step completed in 1.80e+00 s
# Working on    C200704131824A.XR.RBY
#   step completed in 1.86e+00 s
# Working on    C200704131824A.XR.SAG
#   step completed in 1.95e+00 s
# Working on    C200704131824A.XR.TFS
#   step completed in 1.73e+00 s
# Working on    C200704131824A.XR.WSM
#   step completed in 1.96e+00 s
# Working on    C200704131824A.XR.YRT
#   step completed in 2.07e+00 s
# Working on    C200704131824A.XZ.BAGL
#   step completed in 1.99e+00 s
# Working on    C200704131824A.XZ.BARK
#   step completed in 2.21e+00 s
# Working on    C200704131824A.XZ.BARN
#   step completed in 2.57e+00 s
# Working on    C200704131824A.XZ.BERG
#   step completed in 2.26e+00 s
# Working on    C200704131824A.XZ.BGLC
#   step completed in 2.01e+00 s
# Working on    C200704131824A.XZ.GOAT
# Working on    C200704131824A.XZ.GRIN
#   step completed in 1.98e+00 s
# Working on    C200704131824A.XZ.GRNC
#   step completed in 1.80e+00 s
# Working on    C200704131824A.XZ.ISLE
#   step completed in 9.92e-01 s
# Working on    C200704131824A.XZ.KHIT
#   step completed in 1.71e+00 s
# Working on    C200704131824A.XZ.KIAG
#   step completed in 2.07e+00 s
# Working on    C200704131824A.XZ.KULT
#   step completed in 1.82e+00 s
# Working on    C200704131824A.XZ.LOGN
#   step completed in 1.97e+00 s
# Working on    C200704131824A.XZ.MCAR
#   step completed in 1.95e+00 s
# Working on    C200704131824A.XZ.MESA
#   step completed in 2.01e+00 s
# Working on    C200704131824A.XZ.NICH
#   step completed in 1.87e+00 s
# Working on    C200704131824A.XZ.PTPK
#   step completed in 1.73e+00 s
# Working on    C200704131824A.XZ.RKAV
#   step completed in 1.67e+00 s
# Working on    C200704131824A.XZ.SAMH
#   step completed in 1.94e+00 s
# Working on    C200704131824A.XZ.SUCK
#   step completed in 2.13e+00 s
# Working on    C200704131824A.XZ.TABL
#   step completed in 2.05e+00 s
# Working on    C200704131824A.XZ.VRDI
#   step completed in 1.99e+00 s
# Working on    C200704131824A.YV.BING
#   step completed in 1.81e+00 s
# Working on    C200704131824A.YV.HOPJ
#   step completed in 1.91e+00 s
# Working on    C200704131824A.YV.NANC
#   step completed in 1.75e+00 s
# Working on    C200704131824A.YV.PORT
#   step completed in 1.80e+00 s
# Working on    C200704160124A.CN.FRB
#   step completed in 2.65e+00 s
# Working on    C200704160124A.GE.SFJD
# Working on    C200704160124A.IU.SFJD
# Working on    C200704211753A.AT.SIT
# Working on    C200704211753A.CN.BBB
#   step completed in 2.40e+00 s
# Working on    C200704211753A.CN.DRLN
#   step completed in 2.42e+00 s
# Working on    C200704211753A.CN.FRB
#   step completed in 2.51e+00 s
# Working on    C200704211753A.CN.LLLB
#   step completed in 2.43e+00 s
# Working on    C200704211753A.CN.SCHQ
#   step completed in 2.50e+00 s
# Working on    C200704211753A.CN.ULM
#   step completed in 2.32e+00 s
# Working on    C200704211753A.CN.YKW1
#   step completed in 2.49e+00 s
# Working on    C200704211753A.CN.YKW2
#   step completed in 2.13e+00 s
# Working on    C200704211753A.CN.YKW3
#   step completed in 2.15e+00 s
# Working on    C200704211753A.CN.YKW4
#   step completed in 2.26e+00 s
# Working on    C200704211753A.GE.SFJD
# Working on    C200704211753A.II.FFC
#   step completed in 3.30e+00 s
# Working on    C200704211753A.IU.BILL
#   step completed in 2.31e+00 s
# Working on    C200704211753A.IU.MA2
#   step completed in 2.13e+00 s
# Working on    C200704211753A.IU.PET
#   step completed in 2.46e+00 s
# Working on    C200704211753A.IU.SFJD
#   step completed in 3.81e+00 s
# Working on    C200704211753A.IU.TIXI
#   step completed in 2.40e+00 s
# Working on    C200704211753A.IU.YAK
#   step completed in 2.26e+00 s
# Working on    C200704211753A.LI.LTH
#   step completed in 2.66e+00 s
# Working on    C200704211753A.PB.B001
#   step completed in 1.82e+00 s
# Working on    C200704211753A.PB.B003
#   step completed in 1.62e+00 s
# Working on    C200704211753A.PB.B004
#   step completed in 1.86e+00 s
# Working on    C200704211753A.PB.B005
#   step completed in 1.93e+00 s
# Working on    C200704211753A.PB.B006
#   step completed in 1.64e+00 s
# Working on    C200704211753A.PB.B007
#   step completed in 1.73e+00 s
# Working on    C200704211753A.PB.B009
#   step completed in 1.53e+00 s
# Working on    C200704211753A.PB.B010
# Working on    C200704211753A.PB.B011
#   step completed in 1.78e+00 s
# Working on    C200704211753A.PB.B012
#   step completed in 1.94e+00 s
# Working on    C200704211753A.PB.B013
# Working on    C200704211753A.PB.B018
#   step completed in 1.68e+00 s
# Working on    C200704211753A.PB.B022
#   step completed in 1.93e+00 s
# Working on    C200704211753A.TA.A04A
#   step completed in 1.95e+00 s
# Working on    C200704211753A.TA.A05A
#   step completed in 1.72e+00 s
# Working on    C200704211753A.TA.A06A
#   step completed in 1.95e+00 s
# Working on    C200704211753A.TA.A07A
#   step completed in 1.80e+00 s
# Working on    C200704211753A.TA.A08A
#   step completed in 1.78e+00 s
# Working on    C200704211753A.TA.A09A
#   step completed in 1.93e+00 s
# Working on    C200704211753A.TA.A10A
#   step completed in 1.90e+00 s
# Working on    C200704211753A.TA.A11A
#   step completed in 2.16e+00 s
# Working on    C200704211753A.TA.A12A
#   step completed in 1.94e+00 s
# Working on    C200704211753A.TA.A13A
#   step completed in 1.83e+00 s
# Working on    C200704211753A.TA.B04A
#   step completed in 1.84e+00 s
# Working on    C200704211753A.TA.B05A
#   step completed in 1.95e+00 s
# Working on    C200704211753A.TA.B06A
#   step completed in 1.83e+00 s
# Working on    C200704211753A.TA.B07A
#   step completed in 1.85e+00 s
# Working on    C200704211753A.TA.B08A
#   step completed in 1.83e+00 s
# Working on    C200704211753A.TA.B09A
#   step completed in 2.06e+00 s
# Working on    C200704211753A.TA.B10A
#   step completed in 2.13e+00 s
# Working on    C200704211753A.TA.B11A
#   step completed in 2.03e+00 s
# Working on    C200704211753A.TA.B12A
#   step completed in 1.85e+00 s
# Working on    C200704211753A.TA.B13A
#   step completed in 1.85e+00 s
# Working on    C200704211753A.TA.C03A
# ...
#   step completed in 1.95e+00 s
# Working on    C201711201851A.N4.Q56A
#   step completed in 1.53e+00 s
# Working on    C201711201851A.N4.R53A
#   step completed in 1.77e+00 s
# Working on    C201711201851A.N4.R55A
#   step completed in 1.63e+00 s
# Working on    C201711201851A.N4.R58B
#   step completed in 2.20e+00 s
# Working on    C201711201851A.N4.R61A
#   step completed in 1.91e+00 s
# Working on    C201711201851A.N4.S54A
#   step completed in 1.83e+00 s
# Working on    C201711201851A.N4.S57A
#   step completed in 1.97e+00 s
# Working on    C201711201851A.N4.S61A
#   step completed in 1.79e+00 s
# Working on    C201711201851A.N4.T57A
#   step completed in 1.70e+00 s
# Working on    C201711201851A.N4.T59A
#   step completed in 2.14e+00 s
# Working on    C201711201851A.N4.T60A
#   step completed in 1.61e+00 s
# Working on    C201711201851A.N4.U54A
#   step completed in 1.73e+00 s
# Working on    C201711201851A.N4.U56A
#   step completed in 1.82e+00 s
# Working on    C201711201851A.N4.U59A
#   step completed in 1.73e+00 s
# Working on    C201711201851A.N4.V51A
#   step completed in 1.99e+00 s
# Working on    C201711201851A.N4.V52A
#   step completed in 1.84e+00 s
# Working on    C201711201851A.N4.V53A
#   step completed in 1.70e+00 s
# Working on    C201711201851A.N4.V55A
#   step completed in 1.94e+00 s
# Working on    C201711201851A.N4.V58A
#   step completed in 1.85e+00 s
# Working on    C201711201851A.N4.V61A
#   step completed in 1.83e+00 s
# Working on    C201711201851A.N4.W50A
#   step completed in 1.73e+00 s
# Working on    C201711201851A.N4.W52A
#   step completed in 1.83e+00 s
# Working on    C201711201851A.N4.W57A
#   step completed in 1.57e+00 s
# Working on    C201711201851A.N4.W59A
#   step completed in 1.98e+00 s
# Working on    C201711201851A.N4.X51A
#   step completed in 1.94e+00 s
# Working on    C201711201851A.N4.X58A
#   step completed in 1.90e+00 s
# Working on    C201711201851A.N4.Y49A
#   step completed in 1.81e+00 s
# Working on    C201711201851A.N4.Y52A
#   step completed in 1.94e+00 s
# Working on    C201711201851A.N4.Y57A
#   step completed in 1.89e+00 s
# Working on    C201711201851A.N4.Y58A
#   step completed in 1.73e+00 s
# Working on    C201711201851A.N4.Y60A
#   step completed in 1.58e+00 s
# Working on    C201711201851A.N4.Z51A
#   step completed in 1.87e+00 s
# Working on    C201711201851A.NE.BCX
#   step completed in 2.51e+00 s
# Working on    C201711201851A.NE.BRYW
#   step completed in 2.39e+00 s
# Working on    C201711201851A.NE.EMMW
#   step completed in 2.20e+00 s
# Working on    C201711201851A.NE.FFD
#   step completed in 1.93e+00 s
# Working on    C201711201851A.NE.HNH
#   step completed in 2.34e+00 s
# Working on    C201711201851A.NE.PQI
#   step completed in 2.16e+00 s
# Working on    C201711201851A.NE.QUA2
#   step completed in 2.30e+00 s
# Working on    C201711201851A.NE.TRY
#   step completed in 2.65e+00 s
# Working on    C201711201851A.NE.VT1
#   step completed in 2.25e+00 s
# Working on    C201711201851A.NE.WES
#   step completed in 2.07e+00 s
# Working on    C201711201851A.NE.WSPT
#   step completed in 1.96e+00 s
# Working on    C201711201851A.NE.WVL
#   step completed in 2.48e+00 s
# Working on    C201711201851A.NE.YLE
#   step completed in 2.44e+00 s
# Working on    C201711201851A.PE.IUPA
# Working on    C201711201851A.PE.PABE
# Working on    C201711201851A.PE.PACW
# Working on    C201711201851A.PE.PAKC
# Working on    C201711201851A.PE.PAKS
# Working on    C201711201851A.PE.PALB
# Working on    C201711201851A.PE.PALR
# Working on    C201711201851A.PE.PAMP
# Working on    C201711201851A.PE.PAPL
# Working on    C201711201851A.PE.PARS
# Working on    C201711201851A.PE.PASH
# Working on    C201711201851A.PE.PSAL
# Working on    C201711201851A.PE.PSBK
# Working on    C201711201851A.PE.PSMA
# Working on    C201711201851A.PE.PSSK
# Working on    C201711201851A.PE.PSUF
# Working on    C201711201851A.TA.KMSC
#   step completed in 1.83e+00 s
# Working on    C201711201851A.TA.L61B
#   step completed in 1.94e+00 s
# Working on    C201711201851A.TA.M65A
#   step completed in 1.78e+00 s
# Working on    C201711201851A.TA.TIGA
#   step completed in 1.82e+00 s
# Working on    C201711201851A.US.BINY
#   step completed in 1.94e+00 s
# Working on    C201711201851A.US.BLA
#   step completed in 2.02e+00 s
# Working on    C201711201851A.US.BRAL
#   step completed in 1.92e+00 s
# Working on    C201711201851A.US.CBN
#   step completed in 2.97e+00 s
# Working on    C201711201851A.US.CNNC
#   step completed in 2.21e+00 s
# Working on    C201711201851A.US.GOGA
#   step completed in 3.46e+00 s
# Working on    C201711201851A.US.LBNH
#   step completed in 2.13e+00 s
# Working on    C201711201851A.US.LRAL
#   step completed in 1.70e+00 s
# Working on    C201711201851A.US.MCWV
#   step completed in 1.73e+00 s
# Working on    C201711201851A.US.NHSC
#   step completed in 1.90e+00 s
# Working on    C201711201851A.US.PKME
#   step completed in 1.91e+00 s
# Working on    C201711201851A.US.TZTN
#   step completed in 1.71e+00 s
# Working on    C201711270711A.G.MPG
#   step completed in 2.05e+00 s
# Working on    C201711300632A.BK.BDM
# Working on    C201711300632A.BK.BKS
# Working on    C201711300632A.BK.BL67
# Working on    C201711300632A.BK.BRK
# Working on    C201711300632A.BK.CMB
#   step completed in 1.65e+00 s
# Working on    C201711300632A.BK.CVS
# Working on    C201711300632A.BK.DANT
# Working on    C201711300632A.BK.DCMP
# Working on    C201711300632A.BK.FARB
# Working on    C201711300632A.BK.GASB
# Working on    C201711300632A.BK.HAST
# Working on    C201711300632A.BK.HATC
# Working on    C201711300632A.BK.HELL
# Working on    C201711300632A.BK.HOPS
# Working on    C201711300632A.BK.HULI
# Working on    C201711300632A.BK.JCC
# Working on    C201711300632A.BK.JRSC
# Working on    C201711300632A.BK.KCC
# Working on    C201711300632A.BK.MCCM
#   step completed in 1.75e+00 s
# Working on    C201711300632A.BK.MHC
# Working on    C201711300632A.BK.MNRC
# Working on    C201711300632A.BK.MOD
# Working on    C201711300632A.BK.MTOS
# Working on    C201711300632A.BK.ORV
# Working on    C201711300632A.BK.PACP
# Working on    C201711300632A.BK.PETY
# Working on    C201711300632A.BK.PKD
# Working on    C201711300632A.BK.RAMR
# Working on    C201711300632A.BK.SAO
#   step completed in 1.65e+00 s
# Working on    C201711300632A.BK.SCOT
# Working on    C201711300632A.BK.SCZ
# Working on    C201711300632A.BK.SHEP
# Working on    C201711300632A.BK.SUTB
# Working on    C201711300632A.BK.TCAS
# Working on    C201711300632A.BK.TCHL
# Working on    C201711300632A.BK.THIS
# Working on    C201711300632A.BK.TRAM
# Working on    C201711300632A.BK.TRAY
# Working on    C201711300632A.BK.TRIN
# Working on    C201711300632A.BK.TSCN
# Working on    C201711300632A.BK.TSCS
# Working on    C201711300632A.BK.VAK
# Working on    C201711300632A.BK.WDC
# Working on    C201711300632A.BK.WENL
# Working on    C201711300632A.BK.YBH
# Working on    C201711300632A.CI.ARV
#   step completed in 1.91e+00 s
# Working on    C201711300632A.CI.BAK
#   step completed in 1.83e+00 s
# Working on    C201711300632A.CI.BCW
# Working on    C201711300632A.CI.BLC
# Working on    C201711300632A.CI.CAR
# Working on    C201711300632A.CI.CHR
# Working on    C201711300632A.CI.CRG
# Working on    C201711300632A.CI.FIG
# Working on    C201711300632A.CI.GATR
# Working on    C201711300632A.CI.HDH
# Working on    C201711300632A.CI.LCP
# Working on    C201711300632A.CI.LJR
# Working on    C201711300632A.CI.LMY
# Working on    C201711300632A.CI.LOC
# Working on    C201711300632A.CI.MLAC
#   step completed in 2.65e+00 s
# Working on    C201711300632A.CI.MOP
# Working on    C201711300632A.CI.MPI
# Working on    C201711300632A.CI.MPP
#   step completed in 1.76e+00 s
# Working on    C201711300632A.CI.NCH
# Working on    C201711300632A.CI.NJQ
# Working on    C201711300632A.CI.OAT
# Working on    C201711300632A.CI.OSI
#   step completed in 2.27e+00 s
# Working on    C201711300632A.CI.PHL
#   step completed in 1.87e+00 s
# Working on    C201711300632A.CI.QLC
# Working on    C201711300632A.CI.RFR
# Working on    C201711300632A.CI.RSI
# Working on    C201711300632A.CI.SBC
#   step completed in 1.83e+00 s
# Working on    C201711300632A.CI.SBI
# Working on    C201711300632A.CI.SCI2
# Working on    C201711300632A.CI.SCZ2
#   step completed in 1.85e+00 s
# Working on    C201711300632A.CI.SES
# Working on    C201711300632A.CI.SMI
# Working on    C201711300632A.CI.SMM
#   step completed in 1.84e+00 s
# Working on    C201711300632A.CI.SMR
# Working on    C201711300632A.CI.SMW
# Working on    C201711300632A.CI.SNCC
#   step completed in 2.04e+00 s
# Working on    C201711300632A.CI.SPF
# Working on    C201711300632A.CI.SPG2
# Working on    C201711300632A.CI.SRI
# Working on    C201711300632A.CI.STC
# Working on    C201711300632A.CI.SYN
# Working on    C201711300632A.CI.SYP
# Working on    C201711300632A.CI.TFT
# Working on    C201711300632A.CI.VES
#   step completed in 1.82e+00 s
# Working on    C201711300632A.CI.VOG
#   step completed in 2.02e+00 s
# Working on    C201711300632A.CI.WGR
# Working on    C201711300632A.CI.WSS
# Working on    C201711300632A.CI.YEG2
# Working on    C201711300632A.IU.JOHN
#   step completed in 3.33e+00 s
# Working on    C201711300632A.IU.TARA
# Working on    C201711300632A.NC.LBR
# Working on    C201711300632A.NC.LDL
# Working on    C201711300632A.NC.LGY
# Working on    C201711300632A.PB.B039
#   step completed in 2.24e+00 s
# Working on    C201711300632A.PB.B040
#   step completed in 1.87e+00 s
# Working on    C201711300632A.PB.B045
#   step completed in 1.73e+00 s
# Working on    C201711300632A.PB.B046
#   step completed in 1.73e+00 s
# Working on    C201711300632A.PB.B047
#   step completed in 1.82e+00 s
# Working on    C201711300632A.PB.B049
#   step completed in 1.40e+00 s
# Working on    C201711300632A.PB.B054
#   step completed in 1.82e+00 s
# Working on    C201711300632A.PB.B057
#   step completed in 1.61e+00 s
# Working on    C201711300632A.PB.B058
#   step completed in 1.80e+00 s
# Working on    C201711300632A.PB.B065
#   step completed in 1.74e+00 s
# Working on    C201711300632A.PB.B066
#   step completed in 1.59e+00 s
# Working on    C201711300632A.PB.B067
#   step completed in 1.67e+00 s
# Working on    C201711300632A.PB.B072
#   step completed in 1.86e+00 s
# Working on    C201711300632A.PB.B073
#   step completed in 1.85e+00 s
# Working on    C201711300632A.PB.B075
#   step completed in 1.70e+00 s
# Working on    C201711300632A.PB.B076
#   step completed in 1.75e+00 s
# Working on    C201711300632A.PB.B078
#   step completed in 1.99e+00 s
# Working on    C201711300632A.PB.B079
#   step completed in 1.63e+00 s
# Working on    C201711300632A.PB.B900
#   step completed in 1.63e+00 s
# Working on    C201711300632A.PB.B901
#   step completed in 1.87e+00 s
# Working on    C201711300632A.PB.B932
#   step completed in 1.84e+00 s
# Working on    C201711300632A.PB.B933
#   step completed in 1.69e+00 s
# Working on    C201711300632A.PB.B934
#   step completed in 1.82e+00 s
# Working on    C201711300632A.PB.B935
#   step completed in 1.61e+00 s
# Working on    C201711300632A.SB.CPSLO
# Working on    C201712031119A.IU.MIDW
#   step completed in 2.27e+00 s
# Working on    C201712031119A.IU.TARA
# Working on    C201712031119A.IU.WAKE
#   step completed in 3.46e+00 s
# Working on    C201712080209A.II.CMLA
#   step completed in 3.96e+00 s
# Working on    C201712080209A.N4.146B
#   step completed in 1.70e+00 s
# Working on    C201712080209A.N4.152A
#   step completed in 1.70e+00 s
# Working on    C201712080209A.N4.154A
#   step completed in 1.70e+00 s
# Working on    C201712080209A.N4.250A
#   step completed in 1.84e+00 s
# Working on    C201712080209A.N4.255A
#   step completed in 1.72e+00 s
# Working on    C201712080209A.N4.257A
#   step completed in 1.93e+00 s
# Working on    C201712080209A.N4.344B
# Working on    C201712080209A.N4.346B
#   step completed in 2.23e+00 s
# Working on    C201712080209A.N4.352A
#   step completed in 1.96e+00 s
# Working on    C201712080209A.N4.451A
#   step completed in 2.14e+00 s
# Working on    C201712080209A.N4.456A
#   step completed in 2.16e+00 s
# Working on    C201712080209A.N4.M52A
#   step completed in 1.97e+00 s
# Working on    C201712080209A.N4.N51A
#   step completed in 2.04e+00 s
# Working on    C201712080209A.N4.N53A
#   step completed in 1.71e+00 s
# Working on    C201712080209A.N4.O52A
#   step completed in 1.70e+00 s
# Working on    C201712080209A.N4.O54A
#   step completed in 1.92e+00 s
# Working on    C201712080209A.N4.P51A
#   step completed in 1.86e+00 s
# Working on    C201712080209A.N4.P53A
#   step completed in 1.71e+00 s
# Working on    C201712080209A.N4.Q51A
#   step completed in 1.77e+00 s
# Working on    C201712080209A.N4.Q52A
#   step completed in 2.07e+00 s
# Working on    C201712080209A.N4.Q54A
#   step completed in 1.94e+00 s
# Working on    C201712080209A.N4.R49A
#   step completed in 1.78e+00 s
# Working on    C201712080209A.N4.R50A
#   step completed in 1.83e+00 s
# Working on    C201712080209A.N4.R53A
#   step completed in 1.84e+00 s
# Working on    C201712080209A.N4.R55A
#   step completed in 1.82e+00 s
# Working on    C201712080209A.N4.S51A
#   step completed in 1.94e+00 s
# Working on    C201712080209A.N4.S54A
#   step completed in 2.01e+00 s
# Working on    C201712080209A.N4.T47A
#   step completed in 1.81e+00 s
# Working on    C201712080209A.N4.T50A
#   step completed in 1.90e+00 s
# Working on    C201712080209A.N4.T57A
#   step completed in 1.63e+00 s
# Working on    C201712080209A.N4.U49A
#   step completed in 1.72e+00 s
# Working on    C201712080209A.N4.U54A
#   step completed in 1.70e+00 s
# Working on    C201712080209A.N4.U56A
#   step completed in 1.95e+00 s
# Working on    C201712080209A.N4.V48A
#   step completed in 1.73e+00 s
# Working on    C201712080209A.N4.V51A
#   step completed in 1.83e+00 s
# Working on    C201712080209A.N4.V52A
#   step completed in 1.59e+00 s
# Working on    C201712080209A.N4.V53A
#   step completed in 2.03e+00 s
# Working on    C201712080209A.N4.V55A
#   step completed in 1.92e+00 s
# Working on    C201712080209A.N4.V58A
#   step completed in 1.71e+00 s
# Working on    C201712080209A.N4.W50A
#   step completed in 1.81e+00 s
# Working on    C201712080209A.N4.W52A
#   step completed in 1.90e+00 s
# Working on    C201712080209A.N4.W57A
#   step completed in 1.63e+00 s
# Working on    C201712080209A.N4.W59A
#   step completed in 1.83e+00 s
# Working on    C201712080209A.N4.X48A
#   step completed in 1.69e+00 s
# Working on    C201712080209A.N4.X51A
#   step completed in 1.83e+00 s
# Working on    C201712080209A.N4.X58A
#   step completed in 2.10e+00 s
# Working on    C201712080209A.N4.Y49A
#   step completed in 1.94e+00 s
# Working on    C201712080209A.N4.Y52A
#   step completed in 1.84e+00 s
# Working on    C201712080209A.N4.Y57A
#   step completed in 1.88e+00 s
# Working on    C201712080209A.N4.Y58A
#   step completed in 2.04e+00 s
# Working on    C201712080209A.N4.Y60A
#   step completed in 1.73e+00 s
# Working on    C201712080209A.N4.Z47B
#   step completed in 1.74e+00 s
# Working on    C201712080209A.N4.Z51A
#   step completed in 1.81e+00 s
# Working on    C201712080209A.NM.PLAL
#   step completed in 1.92e+00 s
# Working on    C201712080209A.PE.PARS
# Working on    C201712080209A.PM.PMOZ
# Working on    C201712080209A.PM.ROSA
#   step completed in 2.76e+00 s
# Working on    C201712080209A.TA.KMSC
#   step completed in 2.04e+00 s
# Working on    C201712080209A.TA.O53A
#   step completed in 1.93e+00 s
# Working on    C201712080209A.TA.P49A
#   step completed in 1.71e+00 s
# Working on    C201712080209A.TA.P52A
#   step completed in 1.93e+00 s
# Working on    C201712080209A.TA.TIGA
#   step completed in 1.79e+00 s
# Working on    C201712080209A.US.ACSO
#   step completed in 2.15e+00 s
# Working on    C201712080209A.US.BLA
#   step completed in 1.76e+00 s
# Working on    C201712080209A.US.BRAL
#   step completed in 1.75e+00 s
# Working on    C201712080209A.US.GOGA
#   step completed in 3.07e+00 s
# Working on    C201712080209A.US.LRAL
#   step completed in 2.10e+00 s
# Working on    C201712080209A.US.NHSC
#   step completed in 1.91e+00 s
# Working on    C201712080209A.US.TZTN
#   step completed in 2.41e+00 s
# Working on    C201712080209A.US.VBMS
#   step completed in 1.75e+00 s
# Working on    C201712131803A.AT.SIT
# Working on    C201712131803A.TA.S31K
#   step completed in 1.87e+00 s
# Working on    C201712131803A.TA.S32K
#   step completed in 1.71e+00 s
# Working on    C201712131803A.TA.T33K
#   step completed in 1.68e+00 s
# Working on    C201712131803A.TA.U33K
#   step completed in 2.17e+00 s
# Working on    C201712131803A.TA.U35K
#   step completed in 1.61e+00 s
# Working on    C201712131803A.TA.V35K
#   step completed in 1.67e+00 s
# Working on    C201712131803A.US.WRAK
#   step completed in 3.52e+00 s

# %%
conn.close()
