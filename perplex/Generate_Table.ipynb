# %%
src/vertex << !
my_project
!
# Out:
# Perple_X version 6.8.1, source updated Mar 5, 2018.
#
# Enter the project name (the name assigned in BUILD) [default = my_project]:
#
# Reading problem definition from file: my_project.dat
# Reading thermodynamic data from file: sfo05ver.dat
# Reading solution models from file: not requested
# Writing print output to file: none requested
# Writing plot output to file: my_project.plt
# Writing bulk composition plot output to file: my_project.blk
#
# Reading Perple_X options from: perplex_option.dat
# Writing Perple_X option summary to file: not requested
#
# Perple_X version 6.8.1, source updated Mar 5, 2018.
#
# Perple_X computational option settings for VERTEX:
#
#     Keyword:               Value:     Permitted values [default]:
#
#   Auto-refine options:
#
#     auto_refine            aut        off manual [auto]
#     auto_refine_factor_I    3.0       >=1 [3]
#
#   Free energy minimization options:
#
#     final_resolution:
# ...

# %%
rm *.tab
src/werami << !
my_project
2
2
n
13
n
14
n
0
y
10  150000
800 2200
100 100
0
!
# Out:
# Perple_X version 6.8.1, source updated Mar 5, 2018.
#
# Enter the project name (the name assigned in BUILD) [default = my_project]:
#
# Reading Perple_X options from: perplex_option.dat
# Writing Perple_X option summary to file: not requested
#
# Perple_X version 6.8.1, source updated Mar 5, 2018.
#
# Perple_X computational option settings for WERAMI:
#
#     Keyword:               Value:     Permitted values [default]:
#
#   Input/Output options:
#
#     aqueous_output         T          [F] T
#     aqeuous_species         20        [20] 0-100
#     aq_solvent_composition y          [y] m: y => mol fraction, m => molality
#     aq_solute_composition  m          y [m]: y => mol fraction, m => molality
#     spreadsheet            F          [F] T
#     logarithmic_p          F          [F] T
#     bad_number             NaN        [0.0]
#     composition_constant   F          [F] T
#     composition_phase      mol        [mol] wt
#     composition_system     wt         [wt] mol
# ...

# %%
!cat my_project_1.tab
